# %% [markdown]
# <a href="https://colab.research.google.com/github/AjiteshMahalingam/100-Days-of-Code/blob/main/GoGrammar_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pyspellchecker
# Out:
# Requirement already satisfied: pyspellchecker in /usr/local/lib/python3.7/dist-packages (0.6.2)

# %%
pip install gingerit
# Out:
# Requirement already satisfied: gingerit in /usr/local/lib/python3.7/dist-packages (0.8.2)
# Requirement already satisfied: requests<3.0.0,>=2.25.1 in /usr/local/lib/python3.7/dist-packages (from gingerit) (2.26.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.25.1->gingerit) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.25.1->gingerit) (1.24.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.25.1->gingerit) (2.0.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.25.1->gingerit) (2.10)

# %%
from gingerit.gingerit import GingerIt
from spellchecker import SpellChecker

# %% [markdown]
# ## Construction of English Grammar
#
# Input : English Grammar specifications file
#
# Output : Grammar object
#
# -> English Grammar string processing
#
# -> Construction of Grammar class

# %%
# READING GRAMMAR SPECIFICATIONS

inputFile = open('grammar.txt', 'r')
inputText = inputFile.read()
grammarRules = [ rule.strip() for rule in inputText.split("\n")]
grammarRules
# Out:
# ['S -> NP_SG PAST S1 | NP_SG PAST_PERFECT S1 | NP_SG PAST_CONT_SG S1 | NP_SG PAST_PERFECT_CONT S1 | NP_SG PRES_SG S1 | NP_SG PRES_PERFECT_SG S1 | NP_SG PRES_CONT_SG S1 | NP_SG PRES_PERFECT_CONT_SG S1 | NP_SG FUTURE S1 | NP_SG FUTURE_PERFECT S1 | NP_SG FUTURE_CONT S1 | NP_SG FUTURE_PERFECT_CONT S1 | NP_PL PAST S1 | NP_PL PAST_PERFECT S1 | NP_PL PAST_CONT_PL S1 | NP_PL PAST_PERFECT_CONT S1 | NP_PL PRES_PL S1  | NP_PL PRES_PERFECT_PL S1 | NP_PL PRES_CONT_PL S1 | NP_PL PRES_PERFECT_CONT_PL S1 | NP_PL FUTURE S1 | NP_PL FUTURE_PERFECT S1 | NP_PL FUTURE_CONT S1 | NP_PL FUTURE_PERFECT_CONT S1 | S ADV',
#  'S1 -> NP | ADV',
#  'NP -> NP_SG | NP_PL | PP | NP PP',
#  'NP_SG ->  PRONOUN_SG | PRONOUN_SG NOM_SG| PROPERNOUN | NOM_SG | DET_SG NOM_SG | DET_BOTH NOM_SG | ADV NP_SG | NP_SG CONJ NP',
#  'NOM_SG -> NOUN_SG | ADJ NOUN_SG | NOM_SG NOUN_SG',
#  'NP_PL -> PRONOUN_PL | PRONOUN_PL NOM_PL| NOM_PL | DET_PL NOM_PL | DET_BOTH NOM_PL | ADV NP_PL | NP_PL CONJ NP',
#  'NOM_PL -> NOUN_PL | ADJ NOUN_PL | NOM_PL NOUN_PL',
#  'PP -> PREPOS NP_SG | PREPOS NP_PL',
#  'PAST -> V2 | ADV V2',
#  'PAST_PERFECT -> had V3 | had ADV V3',
#  'PAST_CONT_SG -> was GERUNDV | was ADV GERUNDV',
#  'PAST_CONT_PL -> were GERUNDV | were ADV GERUNDV',
#  'PAST_PERFECT_CONT -> had been GERUNDV | had ADV been GERUNDV',
#  'PRES_SG -> V1_SG | ADV V1_SG',
#  'PRES_PL -> V1_PL | ADV V1_PL',
#  'PRES_PERFECT_SG -> has V3 | has ADV V3',
#  'PRES_PERFECT_PL -> have V3 | have ADV V3',
#  'PRES_CONT_SG -> is GERUNDV | is ADV GERUNDV',
#  'PRES_CONT_PL -> are GERUNDV | are ADV GERUNDV',
#  'PRES_PERFECT_CONT_SG -> has been GERUNDV | has ADV been GERUNDV | has been | has ADV been',
#  'PRES_PERFECT_CONT_PL -> have been GERUNDV | have ADV been GERUNDV',
#  'FUTURE -> will V1_PL | will ADV V1_PL',
#  'FUTURE_PERFECT -> will have V3 | will have ADV V3',
#  'FUTURE_CONT -> will be GERUNDV | will ADV be GERUNDV',
#  'FUTURE_PERFECT_CONT -> will have been GERUNDV | will have ADV been GERUNDV',
#  'PRONOUN_SG -> my | she | he | it | him | i | her | his',
#  'PRONOUN_PL -> they | us | you | we | their',
#  'RELPR_SG -> which',
#  'RELPR_PL -> whom',
#  'PROPERNOUN -> ishwarya | joseph | india | germany | ajitesh | navvya | ritheesh | switzerland | paris | wednesday | january | may | turkey | easter | november | raj | canada | america | john',
#  'NOUN_SG -> sentence | me | kabaddi | friend | patient | parcel | player | moment | morning | grandfather | outlet | evening | programming | building | thinking | mom | weekend | brother | basketball | afternoon | book | accountant | milk | accident | neighbourhood | car | phone | night | airplane | fog | street | dad | bed | fire | house | zoo | cold | pope | cup | sister | party | tea | weather | call | baby | movie | picture | pilot | airport | assignment | week | month | room | homework | husband | year | school | teacher | letter | football | food | mountain | wife | topper | song | show | garden | album',
#  'NOUN_PL -> roses | mountains | goats | films | times | emails | people | children |  specialists | girls | parents | jacksons | cows | boys | books | years | portraits | friends | ages | weeks | letters | peacocks | books',
#  'DET_SG -> a | an | this | that',
#  'DET_PL -> these | all | many | no',
#  'DET_BOTH -> the',
#  'CONJ -> and | but | because | while',
#  'ADJ -> red | delicious | first | few | two | four | three | fun | since | sweet | nice | severe | terrible | hungry | new | whole | last | every | critical',
#  'ADV -> well | gracefully | before | next | very | when | not | whereabouts | constantly | lately | yesterday | ago | tomorrow | early | still | twice | always | already | past | never | today | never | recently | heavily',
#  'PREPOS -> at | in | of | for | by | from | far | on | around | as | to | down',
#  'V1_SG -> climbs | teaches | plays | cooks | is | likes | be | know | am | draws | works | understands | invloves | sings',
#  'V1_PL -> teach | are | sing | give | think | rain | turn | go | see | do | take | study | speak | drink | cook',
#  'GERUNDV -> teaching | running | writing | opening | burning | feeling | enjoying | living | spending | ringing | repairing | visiting | having | climbing | getting | meeting | playing | cleaning | going | looking | suffering | raining | waiting | studying | snowing | seeing | dating | taking | listening | dancing',
#  'V2 -> taught | were | was | went | knew | would | started | received | gave | caught | married | understood | flew | drink | read | made | tired | saw | did',
#  'V3 -> seen | written | given | done | gone | made | flown | painted | fed | met | finished | acted | watched']

# %%
class Grammar :
  def __init__(self, grammarStr) :
    self.input = grammarStr
    self.symbols = set()
    self.terminals = set()
    self.nonterminals = set()
    self.startSymbol = None
    self.grammar = {}

    for production in grammarStr :
      # The partition() method searches for a specified string, and splits the string into a tuple containing three elements.
      head, _, bodies = production.partition(' -> ')
      
      # The nonterminal of the first production is considered to be the start symbol
      if self.startSymbol is None :
        self.startSymbol = head

      self.grammar.setdefault(head, set())
      self.nonterminals.add(head)

      bodies = {tuple(body.strip().split(" ")) for body in ' '.join(bodies.split(" ")).split('|') }

      for body in bodies :
        self.grammar[head].add(body)
        for symbol in body :
          if symbol.isupper() :
            self.nonterminals.add(symbol)
          else :
            self.terminals.add(symbol)  
    
    self.symbols = self.nonterminals | self.terminals

  def __str__ (self) :
    print("Start Symbol : " , self.startSymbol)
    print("Non-terminals : " , self.nonterminals)
    print("Terminals : " , self.terminals)
    print("Productions : ")
    for head in self.grammar :
      for body in self.grammar[head] :
        print(head, "->", body)
    return ""

# %%
G = Grammar(grammarRules)
print(G)
properNouns = set()
for pn in G.grammar["PROPERNOUN"]:
  for noun in pn :
    properNouns.add(noun)
# Out:
# Start Symbol :  S
# Non-terminals :  {'RELPR_PL', 'NP_PL', 'PRES_PERFECT_CONT_PL', 'FUTURE', 'FUTURE_PERFECT_CONT', 'RELPR_SG', 'NOM_PL', 'DET_PL', 'CONJ', 'NP_SG', 'PP', 'DET_BOTH', 'NP', 'NOUN_PL', 'V3', 'GERUNDV', 'ADJ', 'S', 'ADV', 'PRES_PERFECT_SG', 'V2', 'PAST_PERFECT', 'PROPERNOUN', 'PREPOS', 'PRES_PERFECT_PL', 'V1_PL', 'NOM_SG', 'PAST_PERFECT_CONT', 'PRONOUN_PL', 'PAST_CONT_SG', 'V1_SG', 'NOUN_SG', 'PAST', 'PRES_CONT_SG', 'S1', 'PRES_SG', 'PRES_CONT_PL', 'FUTURE_CONT', 'FUTURE_PERFECT', 'DET_SG', 'PRONOUN_SG', 'PAST_CONT_PL', 'PRES_PERFECT_CONT_SG', 'PRES_PL'}
# Terminals :  {'he', 'canada', 'an', 'patient', 'room', 'twice', 'turkey', 'made', 'night', 'jacksons', 'by', 'ritheesh', 'may', 'roses', 'received', 'fire', 'sweet', 'bed', 'album', 'likes', 'wednesday', 'baby', 'done', 'understood', 'two', 'am', 'my', 'emails', 'times', 'mom', 'in', 'tomorrow', 'every', 'brother', 'it', 'red', 'phone', 'outlet', 'november', 'accountant', 'boys', 'garden', 'specialists', 'many', 'sister', 'had', 'living', 'whole', 'dad', 'to', 'teacher', 'snowing', 'neighbourhood', 'delicious', 'dancing', 'topper', 'films', 'which', 'teaches', 'taking', 'car', 'and', 'that', 'portraits', 'tea', 'will', 'fog', 'teach', 'morning', 'would', 'climbing', 'on', 'books', 'switzerland', 'children', 'girls', 'works', 'studying', 'ishwarya', 'severe', 'because', 'climbs', 'for', 'think', 'since', 'ringing', 'peacocks', 'looking', 'gone', 'their', 'i', 'husband', 'acted', 'they', 'weather', 'show', 'as', 'assignment', 'party', 'cows', 'nice', 'give', 'burning', 'taught', 'having', 'fed', 'milk', 'started', 'see', 'heavily', 'street', 'grandfather', 'years', 'terrible', 'food', 'speak', 'flew', 'weeks', 'take', 'sings', 'when', 'easter', 'cold', 'gracefully', 'the', 'never', 'us', 'listening', 'past', 'running', 'going', 'has', 'at', 'opening', 'mountain', 'pilot', 'we', 'evening', 'constantly', 'flown', 'homework', 'raj', 'went', 'before', 'sing', 'january', 'early', 'ages', 'today', 'house', 'down', 'given', 'accident', 'yesterday', 'playing', 'kabaddi', 'getting', 'waiting', 'america', 'player', 'already', 'enjoying', 'be', 'raining', 'new', 'teaching', 'wife', 'mountains', 'not', 'you', 'recently', 'far', 'caught', 'john', 'did', 'visiting', 'whom', 'afternoon', 'him', 'goats', 'turn', 'suffering', 'very', 'go', 'gave', 'drink', 'of', 'meeting', 'lately', 'germany', 'his', 'last', 'call', 'well', 'fun', 'week', 'ajitesh', 'moment', 'read', 'her', 'spending', 'four', 'seeing', 'writing', 'finished', 'weekend', 'she', 'met', 'song', 'draws', 'from', 'cooks', 'airport', 'study', 'knew', 'pope', 'first', 'a', 'whereabouts', 'around', 'these', 'basketball', 'invloves', 'do', 'seen', 'have', 'rain', 'written', 'painted', 'parents', 'month', 'thinking', 'programming', 'letters', 'friends', 'cook', 'feeling', 'married', 'watched', 'navvya', 'football', 'were', 'repairing', 'been', 'picture', 'was', 'paris', 'cup', 'movie', 'this', 'three', 'year', 'friend', 'zoo', 'cleaning', 'hungry', 'is', 'letter', 'still', 'are', 'sentence', 'next', 'tired', 'school', 'no', 'while', 'critical', 'know', 'few', 'joseph', 'airplane', 'but', 'plays', 'dating', 'people', 'ago', 'parcel', 'book', 'building', 'understands', 'all', 'india', 'always', 'saw', 'me'}
# Productions :
# S -> ('NP_PL', 'FUTURE', 'S1')
# S -> ('NP_PL', 'FUTURE_PERFECT_CONT', 'S1')
# S -> ('NP_SG', 'PAST_CONT_SG', 'S1')
# S -> ('NP_PL', 'FUTURE_PERFECT', 'S1')
# S -> ('NP_PL', 'PRES_PERFECT_CONT_PL', 'S1')
# S -> ('NP_SG', 'PAST', 'S1')
# S -> ('NP_SG', 'PRES_SG', 'S1')
# S -> ('NP_PL', 'PRES_PL', 'S1')
# S -> ('NP_SG', 'PAST_PERFECT', 'S1')
# S -> ('NP_PL', 'FUTURE_CONT', 'S1')
# S -> ('NP_PL', 'PAST_PERFECT_CONT', 'S1')
# S -> ('S', 'ADV')
# S -> ('NP_SG', 'PRES_CONT_SG', 'S1')
# S -> ('NP_PL', 'PAST_CONT_PL', 'S1')
# S -> ('NP_PL', 'PAST', 'S1')
# S -> ('NP_SG', 'PAST_PERFECT_CONT', 'S1')
# S -> ('NP_SG', 'FUTURE_CONT', 'S1')
# S -> ('NP_SG', 'PRES_PERFECT_SG', 'S1')
# S -> ('NP_PL', 'PRES_PERFECT_PL', 'S1')
# S -> ('NP_SG', 'PRES_PERFECT_CONT_SG', 'S1')
# S -> ('NP_PL', 'PRES_CONT_PL', 'S1')
# S -> ('NP_SG', 'FUTURE_PERFECT_CONT', 'S1')
# S -> ('NP_PL', 'PAST_PERFECT', 'S1')
# S -> ('NP_SG', 'FUTURE_PERFECT', 'S1')
# S -> ('NP_SG', 'FUTURE', 'S1')
# S1 -> ('NP',)
# S1 -> ('ADV',)
# NP -> ('PP',)
# NP -> ('NP', 'PP')
# NP -> ('NP_PL',)
# NP -> ('NP_SG',)
# NP_SG -> ('NP_SG', 'CONJ', 'NP')
# NP_SG -> ('PRONOUN_SG',)
# NP_SG -> ('DET_BOTH', 'NOM_SG')
# NP_SG -> ('ADV', 'NP_SG')
# NP_SG -> ('PROPERNOUN',)
# NP_SG -> ('DET_SG', 'NOM_SG')
# NP_SG -> ('NOM_SG',)
# NP_SG -> ('PRONOUN_SG', 'NOM_SG')
# NOM_SG -> ('ADJ', 'NOUN_SG')
# NOM_SG -> ('NOM_SG', 'NOUN_SG')
# NOM_SG -> ('NOUN_SG',)
# NP_PL -> ('DET_BOTH', 'NOM_PL')
# NP_PL -> ('NOM_PL',)
# NP_PL -> ('ADV', 'NP_PL')
# NP_PL -> ('DET_PL', 'NOM_PL')
# NP_PL -> ('NP_PL', 'CONJ', 'NP')
# NP_PL -> ('PRONOUN_PL', 'NOM_PL')
# NP_PL -> ('PRONOUN_PL',)
# NOM_PL -> ('ADJ', 'NOUN_PL')
# NOM_PL -> ('NOM_PL', 'NOUN_PL')
# NOM_PL -> ('NOUN_PL',)
# PP -> ('PREPOS', 'NP_PL')
# PP -> ('PREPOS', 'NP_SG')
# PAST -> ('ADV', 'V2')
# PAST -> ('V2',)
# PAST_PERFECT -> ('had', 'V3')
# PAST_PERFECT -> ('had', 'ADV', 'V3')
# PAST_CONT_SG -> ('was', 'ADV', 'GERUNDV')
# PAST_CONT_SG -> ('was', 'GERUNDV')
# PAST_CONT_PL -> ('were', 'GERUNDV')
# PAST_CONT_PL -> ('were', 'ADV', 'GERUNDV')
# PAST_PERFECT_CONT -> ('had', 'been', 'GERUNDV')
# PAST_PERFECT_CONT -> ('had', 'ADV', 'been', 'GERUNDV')
# PRES_SG -> ('ADV', 'V1_SG')
# PRES_SG -> ('V1_SG',)
# PRES_PL -> ('ADV', 'V1_PL')
# PRES_PL -> ('V1_PL',)
# PRES_PERFECT_SG -> ('has', 'ADV', 'V3')
# PRES_PERFECT_SG -> ('has', 'V3')
# PRES_PERFECT_PL -> ('have', 'V3')
# PRES_PERFECT_PL -> ('have', 'ADV', 'V3')
# PRES_CONT_SG -> ('is', 'ADV', 'GERUNDV')
# PRES_CONT_SG -> ('is', 'GERUNDV')
# PRES_CONT_PL -> ('are', 'ADV', 'GERUNDV')
# PRES_CONT_PL -> ('are', 'GERUNDV')
# PRES_PERFECT_CONT_SG -> ('has', 'been', 'GERUNDV')
# PRES_PERFECT_CONT_SG -> ('has', 'ADV', 'been', 'GERUNDV')
# PRES_PERFECT_CONT_SG -> ('has', 'been')
# PRES_PERFECT_CONT_SG -> ('has', 'ADV', 'been')
# PRES_PERFECT_CONT_PL -> ('have', 'been', 'GERUNDV')
# PRES_PERFECT_CONT_PL -> ('have', 'ADV', 'been', 'GERUNDV')
# FUTURE -> ('will', 'ADV', 'V1_PL')
# FUTURE -> ('will', 'V1_PL')
# FUTURE_PERFECT -> ('will', 'have', 'ADV', 'V3')
# FUTURE_PERFECT -> ('will', 'have', 'V3')
# FUTURE_CONT -> ('will', 'ADV', 'be', 'GERUNDV')
# FUTURE_CONT -> ('will', 'be', 'GERUNDV')
# FUTURE_PERFECT_CONT -> ('will', 'have', 'been', 'GERUNDV')
# FUTURE_PERFECT_CONT -> ('will', 'have', 'ADV', 'been', 'GERUNDV')
# PRONOUN_SG -> ('she',)
# PRONOUN_SG -> ('his',)
# PRONOUN_SG -> ('he',)
# PRONOUN_SG -> ('him',)
# PRONOUN_SG -> ('my',)
# PRONOUN_SG -> ('i',)
# PRONOUN_SG -> ('her',)
# PRONOUN_SG -> ('it',)
# PRONOUN_PL -> ('you',)
# PRONOUN_PL -> ('their',)
# PRONOUN_PL -> ('we',)
# PRONOUN_PL -> ('they',)
# PRONOUN_PL -> ('us',)
# RELPR_SG -> ('which',)
# RELPR_PL -> ('whom',)
# PROPERNOUN -> ('ritheesh',)
# PROPERNOUN -> ('january',)
# PROPERNOUN -> ('joseph',)
# PROPERNOUN -> ('raj',)
# PROPERNOUN -> ('germany',)
# PROPERNOUN -> ('turkey',)
# PROPERNOUN -> ('november',)
# PROPERNOUN -> ('ajitesh',)
# PROPERNOUN -> ('america',)
# PROPERNOUN -> ('switzerland',)
# PROPERNOUN -> ('paris',)
# PROPERNOUN -> ('ishwarya',)
# PROPERNOUN -> ('easter',)
# PROPERNOUN -> ('navvya',)
# PROPERNOUN -> ('may',)
# PROPERNOUN -> ('wednesday',)
# PROPERNOUN -> ('john',)
# PROPERNOUN -> ('india',)
# PROPERNOUN -> ('canada',)
# NOUN_SG -> ('building',)
# NOUN_SG -> ('morning',)
# NOUN_SG -> ('cold',)
# NOUN_SG -> ('football',)
# NOUN_SG -> ('cup',)
# NOUN_SG -> ('airplane',)
# NOUN_SG -> ('patient',)
# NOUN_SG -> ('homework',)
# NOUN_SG -> ('kabaddi',)
# NOUN_SG -> ('year',)
# NOUN_SG -> ('airport',)
# NOUN_SG -> ('basketball',)
# NOUN_SG -> ('husband',)
# NOUN_SG -> ('zoo',)
# NOUN_SG -> ('fog',)
# NOUN_SG -> ('phone',)
# NOUN_SG -> ('neighbourhood',)
# NOUN_SG -> ('street',)
# NOUN_SG -> ('bed',)
# NOUN_SG -> ('wife',)
# NOUN_SG -> ('moment',)
# NOUN_SG -> ('pilot',)
# NOUN_SG -> ('house',)
# NOUN_SG -> ('song',)
# NOUN_SG -> ('picture',)
# NOUN_SG -> ('food',)
# NOUN_SG -> ('topper',)
# NOUN_SG -> ('evening',)
# NOUN_SG -> ('album',)
# NOUN_SG -> ('book',)
# NOUN_SG -> ('night',)
# NOUN_SG -> ('thinking',)
# NOUN_SG -> ('mom',)
# NOUN_SG -> ('pope',)
# NOUN_SG -> ('letter',)
# NOUN_SG -> ('programming',)
# NOUN_SG -> ('dad',)
# NOUN_SG -> ('baby',)
# NOUN_SG -> ('weather',)
# NOUN_SG -> ('sentence',)
# NOUN_SG -> ('teacher',)
# NOUN_SG -> ('accident',)
# NOUN_SG -> ('show',)
# NOUN_SG -> ('week',)
# NOUN_SG -> ('me',)
# NOUN_SG -> ('room',)
# NOUN_SG -> ('tea',)
# NOUN_SG -> ('friend',)
# NOUN_SG -> ('fire',)
# NOUN_SG -> ('milk',)
# NOUN_SG -> ('sister',)
# NOUN_SG -> ('mountain',)
# NOUN_SG -> ('brother',)
# NOUN_SG -> ('outlet',)
# NOUN_SG -> ('grandfather',)
# NOUN_SG -> ('accountant',)
# NOUN_SG -> ('school',)
# NOUN_SG -> ('assignment',)
# NOUN_SG -> ('call',)
# NOUN_SG -> ('player',)
# NOUN_SG -> ('party',)
# NOUN_SG -> ('movie',)
# NOUN_SG -> ('parcel',)
# NOUN_SG -> ('car',)
# NOUN_SG -> ('garden',)
# NOUN_SG -> ('month',)
# NOUN_SG -> ('afternoon',)
# NOUN_SG -> ('weekend',)
# NOUN_PL -> ('specialists',)
# NOUN_PL -> ('weeks',)
# NOUN_PL -> ('peacocks',)
# NOUN_PL -> ('portraits',)
# NOUN_PL -> ('children',)
# NOUN_PL -> ('friends',)
# NOUN_PL -> ('girls',)
# NOUN_PL -> ('ages',)
# NOUN_PL -> ('mountains',)
# NOUN_PL -> ('people',)
# NOUN_PL -> ('parents',)
# NOUN_PL -> ('emails',)
# NOUN_PL -> ('cows',)
# NOUN_PL -> ('films',)
# NOUN_PL -> ('roses',)
# NOUN_PL -> ('goats',)
# NOUN_PL -> ('letters',)
# NOUN_PL -> ('boys',)
# NOUN_PL -> ('years',)
# NOUN_PL -> ('books',)
# NOUN_PL -> ('times',)
# NOUN_PL -> ('jacksons',)
# DET_SG -> ('an',)
# DET_SG -> ('a',)
# DET_SG -> ('that',)
# DET_SG -> ('this',)
# DET_PL -> ('these',)
# DET_PL -> ('no',)
# DET_PL -> ('many',)
# DET_PL -> ('all',)
# DET_BOTH -> ('the',)
# CONJ -> ('and',)
# CONJ -> ('because',)
# CONJ -> ('but',)
# CONJ -> ('while',)
# ADJ -> ('red',)
# ADJ -> ('three',)
# ADJ -> ('sweet',)
# ADJ -> ('terrible',)
# ADJ -> ('last',)
# ADJ -> ('first',)
# ADJ -> ('fun',)
# ADJ -> ('nice',)
# ADJ -> ('severe',)
# ADJ -> ('few',)
# ADJ -> ('two',)
# ADJ -> ('four',)
# ADJ -> ('new',)
# ADJ -> ('every',)
# ADJ -> ('delicious',)
# ADJ -> ('critical',)
# ADJ -> ('since',)
# ADJ -> ('hungry',)
# ADJ -> ('whole',)
# ADV -> ('recently',)
# ADV -> ('heavily',)
# ADV -> ('gracefully',)
# ADV -> ('past',)
# ADV -> ('not',)
# ADV -> ('well',)
# ADV -> ('before',)
# ADV -> ('already',)
# ADV -> ('when',)
# ADV -> ('whereabouts',)
# ADV -> ('still',)
# ADV -> ('tomorrow',)
# ADV -> ('lately',)
# ADV -> ('yesterday',)
# ADV -> ('early',)
# ADV -> ('never',)
# ADV -> ('twice',)
# ADV -> ('very',)
# ADV -> ('next',)
# ADV -> ('always',)
# ADV -> ('today',)
# ADV -> ('ago',)
# ADV -> ('constantly',)
# PREPOS -> ('to',)
# PREPOS -> ('down',)
# PREPOS -> ('by',)
# PREPOS -> ('far',)
# PREPOS -> ('at',)
# PREPOS -> ('for',)
# PREPOS -> ('on',)
# PREPOS -> ('as',)
# PREPOS -> ('from',)
# PREPOS -> ('of',)
# PREPOS -> ('in',)
# PREPOS -> ('around',)
# V1_SG -> ('climbs',)
# V1_SG -> ('plays',)
# V1_SG -> ('know',)
# V1_SG -> ('draws',)
# V1_SG -> ('sings',)
# V1_SG -> ('likes',)
# V1_SG -> ('teaches',)
# V1_SG -> ('is',)
# V1_SG -> ('works',)
# V1_SG -> ('understands',)
# V1_SG -> ('cooks',)
# V1_SG -> ('am',)
# V1_SG -> ('be',)
# V1_SG -> ('invloves',)
# V1_PL -> ('go',)
# V1_PL -> ('see',)
# V1_PL -> ('are',)
# V1_PL -> ('think',)
# V1_PL -> ('rain',)
# V1_PL -> ('speak',)
# V1_PL -> ('turn',)
# V1_PL -> ('study',)
# V1_PL -> ('give',)
# V1_PL -> ('take',)
# V1_PL -> ('drink',)
# V1_PL -> ('do',)
# V1_PL -> ('sing',)
# V1_PL -> ('teach',)
# V1_PL -> ('cook',)
# GERUNDV -> ('playing',)
# GERUNDV -> ('looking',)
# GERUNDV -> ('having',)
# GERUNDV -> ('cleaning',)
# GERUNDV -> ('dating',)
# GERUNDV -> ('spending',)
# GERUNDV -> ('snowing',)
# GERUNDV -> ('seeing',)
# GERUNDV -> ('climbing',)
# GERUNDV -> ('taking',)
# GERUNDV -> ('studying',)
# GERUNDV -> ('living',)
# GERUNDV -> ('going',)
# GERUNDV -> ('getting',)
# GERUNDV -> ('opening',)
# GERUNDV -> ('raining',)
# GERUNDV -> ('teaching',)
# GERUNDV -> ('feeling',)
# GERUNDV -> ('writing',)
# GERUNDV -> ('listening',)
# GERUNDV -> ('visiting',)
# GERUNDV -> ('dancing',)
# GERUNDV -> ('running',)
# GERUNDV -> ('ringing',)
# GERUNDV -> ('waiting',)
# GERUNDV -> ('repairing',)
# GERUNDV -> ('burning',)
# GERUNDV -> ('suffering',)
# GERUNDV -> ('enjoying',)
# GERUNDV -> ('meeting',)
# V2 -> ('saw',)
# V2 -> ('caught',)
# V2 -> ('understood',)
# V2 -> ('made',)
# V2 -> ('were',)
# V2 -> ('flew',)
# V2 -> ('knew',)
# V2 -> ('was',)
# V2 -> ('drink',)
# V2 -> ('read',)
# V2 -> ('married',)
# V2 -> ('received',)
# V2 -> ('taught',)
# V2 -> ('tired',)
# V2 -> ('went',)
# V2 -> ('started',)
# V2 -> ('would',)
# V2 -> ('gave',)
# V2 -> ('did',)
# V3 -> ('made',)
# V3 -> ('given',)
# V3 -> ('met',)
# V3 -> ('finished',)
# V3 -> ('done',)
# V3 -> ('acted',)
# V3 -> ('seen',)
# V3 -> ('gone',)
# V3 -> ('written',)
# V3 -> ('painted',)
# V3 -> ('flown',)
# V3 -> ('fed',)
# V3 -> ('watched',)

# %% [markdown]
# ## Construction of SLR(1) Parser Table
#
# Input : English Grammar Object
#
# Output : SLR(1) Parsing table
#
#
# -> First and Follow
#
# -> Canonical collection of LR(0) items
#
# -> Building Parser table

# %%
# Generating first and follow sets

def first_follow(G) :
  def union(set1, set2):
    set1len = len(set1)
    set1 |= set2
    return set1len != len(set1)

  # initialising the data structures to store and first and follow values
  first = { symbol: set() for symbol in G.symbols }
  follow = { symbol: set() for symbol in G.symbols }

  for symbol in G.symbols :
    if symbol in G.terminals :
      first[symbol].add(symbol)
  
  follow[G.startSymbol].add('$')

  while True :
    updated = False

    for head, bodies in G.grammar.items() :
      for body in bodies :
        for symbol in body :
          if symbol != '^':
            updated |= union(first[head], first[symbol] - set('^'))
            if '^' not in first[symbol] :
              break
            else :
              updated |= union(first[head], set('^'))
        aux = follow[head]
        for symbol in reversed(body) :
          if symbol == '^':
            continue
          if symbol in follow:
            updated |= union(follow[symbol], aux - set('^'))
          if '^' in first[symbol] :
            aux = aux | first[symbol]
          else :
            aux = first[symbol]
    if not updated:
      return first, follow

# %%
# Construction of LR(0) items

# Computation of set of items constructed from I
# I - set of items for G
def CLOSURE(aug_G, I):
  J = I
  
  while True :
    item_len = len(J)
    for head, bodies in J.copy().items() :
      for body in bodies.copy():
        if '.' in body[:-1]:
          dot_pos = body.index('.')
          symbol_after_dot = body[dot_pos + 1]
          if symbol_after_dot in aug_G.nonterminals :
            for G_body in aug_G.grammar[symbol_after_dot]:
              if G_body == tuple('^'):
                J.setdefault(symbol_after_dot, set()).add(set('.'))
              else :
                J.setdefault(symbol_after_dot, set()).add(('.',) + G_body)
    if item_len == len(J):
      return J

# GOTO(I, X) defined to be the closure of the set of all items [A -> aX.b] such that [A -> a.Xb] is in I
# I - set of items
# X - grammar symbol
def GOTO(aug_G, I, X):
  goto = {}

  for head, bodies in I.items() :
    for body in bodies :
      if '.' in body[:-1]:
        dot_pos = body.index('.')
        if body[dot_pos + 1] == X :
          replaced_dot_body = body[ : dot_pos] + (X, '.') + body[dot_pos + 2: ]
          for C_head, C_bodies in CLOSURE(aug_G, {head: {replaced_dot_body}}).items():
            goto.setdefault(C_head, set()).update(C_bodies)
  
  return goto

# Construction of canonical collection of sets of LR(0) items for G'
def items(aug_G):
  C = [CLOSURE(aug_G, {aug_G.startSymbol : {('.', aug_G.startSymbol[:-1])}})]

  while True:
    item_len = len(C)
    for I in C.copy() :
      for X in aug_G.symbols:
        goto = GOTO(aug_G, I, X)
        if (len(goto) > 0) and goto not in C:
          C.append(goto)
    if item_len == len(C) :
      return C

# %%
# Construction of SLR(1) Parsing table

class SLRParser:
  def __init__(self, G):
    self.aug_G = Grammar([f"{G.startSymbol}' -> {G.startSymbol}"] + G.input)
    self.max_aug_G_len = len(max(self.aug_G.grammar, key=len))

    self.G_indexed = []
    for head, bodies in self.aug_G.grammar.items():
      for body in bodies:
        self.G_indexed.append([head, body])
    
    self.first, self.follow = first_follow(self.aug_G)

    self.C = items(self.aug_G)
    
    self.action = list(self.aug_G.terminals) + ['$']
    self.goto = []
    for nonterminal in self.aug_G.nonterminals :
      if nonterminal != self.aug_G.startSymbol :
        self.goto.append(nonterminal)
    
    self.parse_table_symbols = self.action + self.goto
    self.parse_table = self.construct_table()
  
  def construct_table(self):
    # Step 1 - Construct C
    # Step 2 - parsing actions for state i are determined
    parse_table = {r: {c: '' for c in self.parse_table_symbols} for r in range(len(self.C))}

    for i, I in enumerate(self.C) :
      for head, bodies in I.items() :
        for body in bodies :
          if '.' in body[:-1] : # Case 2a
            dot_pos = body.index('.')
            symbol_after_dot = body[dot_pos + 1]

            if symbol_after_dot in self.aug_G.terminals :
              s = f's{self.C.index(GOTO(self.aug_G, I, symbol_after_dot))}'
              if s not in parse_table[i][symbol_after_dot]:
                if 'r' in parse_table[i][symbol_after_dot] :
                  parse_table[i][symbol_after_dot] += '/'
                parse_table[i][symbol_after_dot] += s
          
          elif body[-1] == '.' and head != self.aug_G.startSymbol : # Case 2b
            for j, (G_head, G_body) in enumerate(self.G_indexed) :
              if G_head == head and (G_body == body[:-1] or G_body == ('^',) and body == ('.',)):
                for f in self.follow[head] :
                  if parse_table[i][f] :
                    parse_table[i][f] += '/'
                  parse_table[i][f] += f'r{j}'

                break

          else : # Case 2c
            parse_table[i]['$'] = 'acc'
      
      # Step 3 - Goto transistions for all nonterminals are constructed
      for A in self.aug_G.nonterminals :
        j = GOTO(self.aug_G, I, A)
        if j in self.C :
          parse_table[i][A] = self.C.index(j)

    return parse_table

  def __str__ (self) :
    def fprint(text, variable) :
      print(f'{text:>12}: {", ".join(variable)}')
    def print_line() :
      print(f'+{("-" * width + "+") * (len(list(self.aug_G.symbols) + ["$"]))}')
    def symbols_width(symbols) :
      return (width + 1) * len(symbols) - 1

    print("Augmented Grammar : ")
    for i, (head, body) in enumerate(self.G_indexed):
      print(f'{i:>{len(str(len(self.G_indexed) - 1))}}: {head:>{self.max_aug_G_len}} -> {" ".join(body)}')
    print()
    fprint('TERMINALS', self.aug_G.terminals)
    fprint('NONTERMINALS', self.aug_G.nonterminals)
    fprint('SYMBOLS', self.aug_G.symbols)

    print('\nFIRST:')
    for head in self.aug_G.grammar:
      print(f'{head:>{self.max_aug_G_len}} = {{ {", ".join(self.first[head])} }}')

    print('\nFOLLOW:')
    for head in self.aug_G.grammar:
      print(f'{head:>{self.max_aug_G_len}} = {{ {", ".join(self.follow[head])} }}')

    width = max(len(c) for c in {'ACTION'} | self.aug_G.symbols) + 2
    for r in range(len(self.C)):
      max_len = max(len(str(c)) for c in self.parse_table[r].values())

      if width < max_len + 2:
        width = max_len + 2

    print('\nPARSING TABLE:')
    print(f'+{"-" * width}+{"-" * symbols_width(self.action)}+{"-" * symbols_width(self.goto)}+')
    print(f'|{"":{width}}|{"ACTION":^{symbols_width(self.action)}}|{"GOTO":^{symbols_width(self.goto)}}|')
    print(f'|{"STATE":^{width}}+{("-" * width + "+") * len(self.parse_table_symbols)}')
    print(f'|{"":^{width}}|', end=' ')

    for symbol in self.parse_table_symbols:
      print(f'{symbol:^{width - 1}}|', end=' ')

    print()
    print_line()

    for r in range(len(self.C)):
      print(f'|{r:^{width}}|', end=' ')

      for c in self.parse_table_symbols:
        print(f'{self.parse_table[r][c]:^{width - 1}}|', end=' ')

      print()

    print_line()
    print()
    return ""

# %%
slr = SLRParser(G)
print(slr)
# Out:
# Augmented Grammar :
#   0:                   S' -> S
#   1:                    S -> NP_PL FUTURE S1
#   2:                    S -> NP_PL FUTURE_PERFECT_CONT S1
#   3:                    S -> NP_SG PAST_CONT_SG S1
#   4:                    S -> NP_PL FUTURE_PERFECT S1
#   5:                    S -> NP_PL PRES_PERFECT_CONT_PL S1
#   6:                    S -> NP_SG PAST S1
#   7:                    S -> NP_SG PRES_SG S1
#   8:                    S -> NP_PL PRES_PL S1
#   9:                    S -> NP_SG PAST_PERFECT S1
#  10:                    S -> NP_PL FUTURE_CONT S1
#  11:                    S -> NP_PL PAST_PERFECT_CONT S1
#  12:                    S -> S ADV
#  13:                    S -> NP_SG PRES_CONT_SG S1
#  14:                    S -> NP_PL PAST_CONT_PL S1
#  15:                    S -> NP_PL PAST S1
#  16:                    S -> NP_SG PAST_PERFECT_CONT S1
#  17:                    S -> NP_SG FUTURE_CONT S1
#  18:                    S -> NP_SG PRES_PERFECT_SG S1
#  19:                    S -> NP_PL PRES_PERFECT_PL S1
#  20:                    S -> NP_SG PRES_PERFECT_CONT_SG S1
#  21:                    S -> NP_PL PRES_CONT_PL S1
#  22:                    S -> NP_SG FUTURE_PERFECT_CONT S1
#  23:                    S -> NP_PL PAST_PERFECT S1
#  24:                    S -> NP_SG FUTURE_PERFECT S1
#  25:                    S -> NP_SG FUTURE S1
#  26:                   S1 -> NP
#  27:                   S1 -> ADV
#  28:                   NP -> PP
#  29:                   NP -> NP PP
#  30:                   NP -> NP_PL
#  31:                   NP -> NP_SG
#  32:                NP_SG -> NP_SG CONJ NP
#  33:                NP_SG -> PRONOUN_SG
#  34:                NP_SG -> DET_BOTH NOM_SG
#  35:                NP_SG -> ADV NP_SG
#  36:                NP_SG -> PROPERNOUN
#  37:                NP_SG -> DET_SG NOM_SG
#  38:                NP_SG -> NOM_SG
#  39:                NP_SG -> PRONOUN_SG NOM_SG
#  40:               NOM_SG -> ADJ NOUN_SG
#  41:               NOM_SG -> NOM_SG NOUN_SG
#  42:               NOM_SG -> NOUN_SG
#  43:                NP_PL -> DET_BOTH NOM_PL
#  44:                NP_PL -> NOM_PL
#  45:                NP_PL -> ADV NP_PL
#  46:                NP_PL -> DET_PL NOM_PL
#  47:                NP_PL -> NP_PL CONJ NP
#  48:                NP_PL -> PRONOUN_PL NOM_PL
#  49:                NP_PL -> PRONOUN_PL
#  50:               NOM_PL -> ADJ NOUN_PL
#  51:               NOM_PL -> NOM_PL NOUN_PL
#  52:               NOM_PL -> NOUN_PL
#  53:                   PP -> PREPOS NP_PL
#  54:                   PP -> PREPOS NP_SG
#  55:                 PAST -> ADV V2
#  56:                 PAST -> V2
#  57:         PAST_PERFECT -> had V3
#  58:         PAST_PERFECT -> had ADV V3
#  59:         PAST_CONT_SG -> was ADV GERUNDV
#  60:         PAST_CONT_SG -> was GERUNDV
#  61:         PAST_CONT_PL -> were GERUNDV
#  62:         PAST_CONT_PL -> were ADV GERUNDV
#  63:    PAST_PERFECT_CONT -> had been GERUNDV
#  64:    PAST_PERFECT_CONT -> had ADV been GERUNDV
#  65:              PRES_SG -> ADV V1_SG
#  66:              PRES_SG -> V1_SG
#  67:              PRES_PL -> ADV V1_PL
#  68:              PRES_PL -> V1_PL
#  69:      PRES_PERFECT_SG -> has ADV V3
#  70:      PRES_PERFECT_SG -> has V3
#  71:      PRES_PERFECT_PL -> have V3
#  72:      PRES_PERFECT_PL -> have ADV V3
#  73:         PRES_CONT_SG -> is ADV GERUNDV
#  74:         PRES_CONT_SG -> is GERUNDV
#  75:         PRES_CONT_PL -> are ADV GERUNDV
#  76:         PRES_CONT_PL -> are GERUNDV
#  77: PRES_PERFECT_CONT_SG -> has been GERUNDV
#  78: PRES_PERFECT_CONT_SG -> has ADV been GERUNDV
#  79: PRES_PERFECT_CONT_SG -> has been
#  80: PRES_PERFECT_CONT_SG -> has ADV been
#  81: PRES_PERFECT_CONT_PL -> have been GERUNDV
#  82: PRES_PERFECT_CONT_PL -> have ADV been GERUNDV
#  83:               FUTURE -> will ADV V1_PL
#  84:               FUTURE -> will V1_PL
#  85:       FUTURE_PERFECT -> will have ADV V3
#  86:       FUTURE_PERFECT -> will have V3
#  87:          FUTURE_CONT -> will ADV be GERUNDV
#  88:          FUTURE_CONT -> will be GERUNDV
#  89:  FUTURE_PERFECT_CONT -> will have been GERUNDV
#  90:  FUTURE_PERFECT_CONT -> will have ADV been GERUNDV
#  91:           PRONOUN_SG -> she
#  92:           PRONOUN_SG -> his
#  93:           PRONOUN_SG -> he
#  94:           PRONOUN_SG -> him
#  95:           PRONOUN_SG -> my
#  96:           PRONOUN_SG -> i
#  97:           PRONOUN_SG -> her
#  98:           PRONOUN_SG -> it
#  99:           PRONOUN_PL -> you
# 100:           PRONOUN_PL -> their
# 101:           PRONOUN_PL -> we
# 102:           PRONOUN_PL -> they
# 103:           PRONOUN_PL -> us
# 104:             RELPR_SG -> which
# 105:             RELPR_PL -> whom
# 106:           PROPERNOUN -> ritheesh
# 107:           PROPERNOUN -> january
# 108:           PROPERNOUN -> joseph
# 109:           PROPERNOUN -> raj
# 110:           PROPERNOUN -> germany
# 111:           PROPERNOUN -> turkey
# 112:           PROPERNOUN -> november
# 113:           PROPERNOUN -> ajitesh
# 114:           PROPERNOUN -> america
# 115:           PROPERNOUN -> switzerland
# 116:           PROPERNOUN -> paris
# 117:           PROPERNOUN -> ishwarya
# 118:           PROPERNOUN -> easter
# 119:           PROPERNOUN -> navvya
# 120:           PROPERNOUN -> may
# 121:           PROPERNOUN -> wednesday
# 122:           PROPERNOUN -> john
# 123:           PROPERNOUN -> india
# 124:           PROPERNOUN -> canada
# 125:              NOUN_SG -> building
# 126:              NOUN_SG -> morning
# 127:              NOUN_SG -> cold
# 128:              NOUN_SG -> football
# 129:              NOUN_SG -> cup
# 130:              NOUN_SG -> airplane
# 131:              NOUN_SG -> patient
# 132:              NOUN_SG -> homework
# 133:              NOUN_SG -> kabaddi
# 134:              NOUN_SG -> year
# 135:              NOUN_SG -> airport
# 136:              NOUN_SG -> basketball
# 137:              NOUN_SG -> husband
# 138:              NOUN_SG -> zoo
# 139:              NOUN_SG -> fog
# 140:              NOUN_SG -> phone
# 141:              NOUN_SG -> neighbourhood
# 142:              NOUN_SG -> street
# 143:              NOUN_SG -> bed
# 144:              NOUN_SG -> wife
# 145:              NOUN_SG -> moment
# 146:              NOUN_SG -> pilot
# 147:              NOUN_SG -> house
# 148:              NOUN_SG -> song
# 149:              NOUN_SG -> picture
# 150:              NOUN_SG -> food
# 151:              NOUN_SG -> topper
# 152:              NOUN_SG -> evening
# 153:              NOUN_SG -> album
# 154:              NOUN_SG -> book
# 155:              NOUN_SG -> night
# 156:              NOUN_SG -> thinking
# 157:              NOUN_SG -> mom
# 158:              NOUN_SG -> pope
# 159:              NOUN_SG -> letter
# 160:              NOUN_SG -> programming
# 161:              NOUN_SG -> dad
# 162:              NOUN_SG -> baby
# 163:              NOUN_SG -> weather
# 164:              NOUN_SG -> sentence
# 165:              NOUN_SG -> teacher
# 166:              NOUN_SG -> accident
# 167:              NOUN_SG -> show
# 168:              NOUN_SG -> week
# 169:              NOUN_SG -> me
# 170:              NOUN_SG -> room
# 171:              NOUN_SG -> tea
# 172:              NOUN_SG -> friend
# 173:              NOUN_SG -> fire
# 174:              NOUN_SG -> milk
# 175:              NOUN_SG -> sister
# 176:              NOUN_SG -> mountain
# 177:              NOUN_SG -> brother
# 178:              NOUN_SG -> outlet
# 179:              NOUN_SG -> grandfather
# 180:              NOUN_SG -> accountant
# 181:              NOUN_SG -> school
# 182:              NOUN_SG -> assignment
# 183:              NOUN_SG -> call
# 184:              NOUN_SG -> player
# 185:              NOUN_SG -> party
# 186:              NOUN_SG -> movie
# 187:              NOUN_SG -> parcel
# 188:              NOUN_SG -> car
# 189:              NOUN_SG -> garden
# 190:              NOUN_SG -> month
# 191:              NOUN_SG -> afternoon
# 192:              NOUN_SG -> weekend
# 193:              NOUN_PL -> specialists
# 194:              NOUN_PL -> weeks
# 195:              NOUN_PL -> peacocks
# 196:              NOUN_PL -> portraits
# 197:              NOUN_PL -> children
# 198:              NOUN_PL -> friends
# 199:              NOUN_PL -> girls
# 200:              NOUN_PL -> ages
# 201:              NOUN_PL -> mountains
# 202:              NOUN_PL -> people
# 203:              NOUN_PL -> parents
# 204:              NOUN_PL -> emails
# 205:              NOUN_PL -> cows
# 206:              NOUN_PL -> films
# 207:              NOUN_PL -> roses
# 208:              NOUN_PL -> goats
# 209:              NOUN_PL -> letters
# 210:              NOUN_PL -> boys
# 211:              NOUN_PL -> years
# 212:              NOUN_PL -> books
# 213:              NOUN_PL -> times
# 214:              NOUN_PL -> jacksons
# 215:               DET_SG -> an
# 216:               DET_SG -> a
# 217:               DET_SG -> that
# 218:               DET_SG -> this
# 219:               DET_PL -> these
# 220:               DET_PL -> no
# 221:               DET_PL -> many
# 222:               DET_PL -> all
# 223:             DET_BOTH -> the
# 224:                 CONJ -> and
# 225:                 CONJ -> because
# 226:                 CONJ -> but
# 227:                 CONJ -> while
# 228:                  ADJ -> red
# 229:                  ADJ -> three
# 230:                  ADJ -> sweet
# 231:                  ADJ -> terrible
# 232:                  ADJ -> last
# 233:                  ADJ -> first
# 234:                  ADJ -> fun
# 235:                  ADJ -> nice
# 236:                  ADJ -> severe
# 237:                  ADJ -> few
# 238:                  ADJ -> two
# 239:                  ADJ -> four
# 240:                  ADJ -> new
# 241:                  ADJ -> every
# 242:                  ADJ -> delicious
# 243:                  ADJ -> critical
# 244:                  ADJ -> since
# 245:                  ADJ -> hungry
# 246:                  ADJ -> whole
# 247:                  ADV -> recently
# 248:                  ADV -> heavily
# 249:                  ADV -> gracefully
# 250:                  ADV -> past
# 251:                  ADV -> not
# 252:                  ADV -> well
# 253:                  ADV -> before
# 254:                  ADV -> already
# 255:                  ADV -> when
# 256:                  ADV -> whereabouts
# 257:                  ADV -> still
# 258:                  ADV -> tomorrow
# 259:                  ADV -> lately
# 260:                  ADV -> yesterday
# 261:                  ADV -> early
# 262:                  ADV -> never
# 263:                  ADV -> twice
# 264:                  ADV -> very
# 265:                  ADV -> next
# 266:                  ADV -> always
# 267:                  ADV -> today
# 268:                  ADV -> ago
# 269:                  ADV -> constantly
# 270:               PREPOS -> to
# 271:               PREPOS -> down
# 272:               PREPOS -> by
# 273:               PREPOS -> far
# 274:               PREPOS -> at
# 275:               PREPOS -> for
# 276:               PREPOS -> on
# 277:               PREPOS -> as
# 278:               PREPOS -> from
# 279:               PREPOS -> of
# 280:               PREPOS -> in
# 281:               PREPOS -> around
# 282:                V1_SG -> climbs
# 283:                V1_SG -> plays
# 284:                V1_SG -> know
# 285:                V1_SG -> draws
# 286:                V1_SG -> sings
# 287:                V1_SG -> likes
# 288:                V1_SG -> teaches
# 289:                V1_SG -> is
# 290:                V1_SG -> works
# 291:                V1_SG -> understands
# 292:                V1_SG -> cooks
# 293:                V1_SG -> am
# 294:                V1_SG -> be
# 295:                V1_SG -> invloves
# 296:                V1_PL -> go
# 297:                V1_PL -> see
# 298:                V1_PL -> are
# 299:                V1_PL -> think
# 300:                V1_PL -> rain
# 301:                V1_PL -> speak
# 302:                V1_PL -> turn
# 303:                V1_PL -> study
# 304:                V1_PL -> give
# 305:                V1_PL -> take
# 306:                V1_PL -> drink
# 307:                V1_PL -> do
# 308:                V1_PL -> sing
# 309:                V1_PL -> teach
# 310:                V1_PL -> cook
# 311:              GERUNDV -> playing
# 312:              GERUNDV -> looking
# 313:              GERUNDV -> having
# 314:              GERUNDV -> cleaning
# 315:              GERUNDV -> dating
# 316:              GERUNDV -> spending
# 317:              GERUNDV -> snowing
# 318:              GERUNDV -> seeing
# 319:              GERUNDV -> climbing
# 320:              GERUNDV -> taking
# 321:              GERUNDV -> studying
# 322:              GERUNDV -> living
# 323:              GERUNDV -> going
# 324:              GERUNDV -> getting
# 325:              GERUNDV -> opening
# 326:              GERUNDV -> raining
# 327:              GERUNDV -> teaching
# 328:              GERUNDV -> feeling
# 329:              GERUNDV -> writing
# 330:              GERUNDV -> listening
# 331:              GERUNDV -> visiting
# 332:              GERUNDV -> dancing
# 333:              GERUNDV -> running
# 334:              GERUNDV -> ringing
# 335:              GERUNDV -> waiting
# 336:              GERUNDV -> repairing
# 337:              GERUNDV -> burning
# 338:              GERUNDV -> suffering
# 339:              GERUNDV -> enjoying
# 340:              GERUNDV -> meeting
# 341:                   V2 -> saw
# 342:                   V2 -> caught
# 343:                   V2 -> understood
# 344:                   V2 -> made
# 345:                   V2 -> were
# 346:                   V2 -> flew
# 347:                   V2 -> knew
# 348:                   V2 -> was
# 349:                   V2 -> drink
# 350:                   V2 -> read
# 351:                   V2 -> married
# 352:                   V2 -> received
# 353:                   V2 -> taught
# 354:                   V2 -> tired
# 355:                   V2 -> went
# 356:                   V2 -> started
# 357:                   V2 -> would
# 358:                   V2 -> gave
# 359:                   V2 -> did
# 360:                   V3 -> made
# 361:                   V3 -> given
# 362:                   V3 -> met
# 363:                   V3 -> finished
# 364:                   V3 -> done
# 365:                   V3 -> acted
# 366:                   V3 -> seen
# 367:                   V3 -> gone
# 368:                   V3 -> written
# 369:                   V3 -> painted
# 370:                   V3 -> flown
# 371:                   V3 -> fed
# 372:                   V3 -> watched
#
#    TERMINALS: he, canada, an, patient, room, twice, turkey, made, night, jacksons, by, ritheesh, may, roses, received, fire, sweet, bed, album, likes, wednesday, baby, done, understood, two, am, my, emails, times, mom, in, tomorrow, every, brother, it, red, phone, outlet, november, accountant, boys, garden, specialists, many, sister, had, living, whole, dad, to, teacher, snowing, neighbourhood, delicious, dancing, topper, films, which, teaches, taking, car, and, that, portraits, tea, will, fog, teach, morning, would, climbing, on, books, switzerland, children, girls, works, studying, ishwarya, severe, because, climbs, for, think, since, ringing, peacocks, looking, gone, their, i, husband, acted, they, weather, show, as, assignment, party, cows, nice, give, burning, taught, having, fed, milk, started, see, heavily, street, grandfather, years, terrible, food, speak, flew, weeks, take, sings, when, easter, cold, gracefully, the, never, us, listening, past, running, going, has, at, opening, mountain, pilot, we, evening, constantly, flown, homework, raj, went, before, sing, january, early, ages, today, house, down, given, accident, yesterday, playing, kabaddi, getting, waiting, america, player, already, enjoying, be, raining, new, teaching, wife, mountains, not, you, recently, far, caught, john, did, visiting, whom, afternoon, him, goats, turn, suffering, very, go, gave, drink, of, meeting, lately, germany, his, last, call, well, fun, week, ajitesh, moment, read, her, spending, four, seeing, writing, finished, weekend, she, met, song, draws, from, cooks, airport, study, knew, pope, first, a, whereabouts, around, these, basketball, invloves, do, seen, have, rain, written, painted, parents, month, thinking, programming, letters, friends, cook, feeling, married, watched, navvya, football, were, repairing, been, picture, was, paris, cup, movie, this, three, year, friend, zoo, cleaning, hungry, is, letter, still, are, sentence, next, tired, school, no, while, critical, know, few, joseph, airplane, but, plays, dating, people, ago, parcel, book, building, understands, all, india, always, saw, me
# NONTERMINALS: RELPR_PL, NP_PL, PRES_PERFECT_CONT_PL, FUTURE, FUTURE_PERFECT_CONT, RELPR_SG, NOM_PL, DET_PL, CONJ, NP_SG, PP, DET_BOTH, NP, NOUN_PL, V3, GERUNDV, ADJ, S, ADV, PRES_PERFECT_SG, V2, PAST_PERFECT, PROPERNOUN, PREPOS, PRES_PERFECT_PL, V1_PL, NOM_SG, PAST_PERFECT_CONT, PRONOUN_PL, PAST_CONT_SG, V1_SG, NOUN_SG, PAST, PRES_CONT_SG, S1, PRES_SG, PRES_CONT_PL, S', FUTURE_CONT, FUTURE_PERFECT, DET_SG, PRONOUN_SG, PAST_CONT_PL, PRES_PERFECT_CONT_SG, PRES_PL
#      SYMBOLS: canada, RELPR_PL, an, patient, turkey, made, night, jacksons, received, likes, wednesday, CONJ, understood, two, am, NP_SG, mom, every, brother, phone, PREPOS, november, boys, specialists, many, sister, had, living, whole, to, teacher, snowing, neighbourhood, topper, films, PRES_SG, S', taking, and, portraits, morning, NP_PL, FUTURE, children, works, ishwarya, severe, because, climbs, for, think, since, peacocks, acted, V2, assignment, burning, nice, V1_PL, taught, NOM_SG, fed, milk, see, street, grandfather, years, terrible, food, speak, flew, weeks, sings, when, easter, cold, gracefully, never, us, PRONOUN_SG, at, opening, mountain, evening, raj, ages, given, yesterday, playing, getting, kabaddi, america, already, enjoying, be, raining, wife, mountains, far, caught, john, visiting, afternoon, suffering, very, go, drink, germany, his, PAST, call, week, PRES_CONT_PL, ajitesh, spending, seeing, writing, she, met, draws, from, cooks, airport, study, knew, pope, whereabouts, a, invloves, do, basketball, have, rain, written, painted, parents, NOUN_PL, letters, friends, feeling, watched, navvya, football, were, would, fun, been, PRES_PERFECT_PL, picture, was, paris, movie, year, friend, cleaning, is, PRONOUN_PL, are, sentence, tired, critical, know, dating, people, ago, FUTURE_PERFECT, building, all, india, saw, me, he, room, twice, NOM_PL, by, ritheesh, may, roses, fire, sweet, bed, album, baby, done, my, emails, times, in, tomorrow, ADV, it, red, outlet, accountant, garden, dad, delicious, dancing, which, teaches, car, that, tea, will, fog, teach, climbing, on, books, switzerland, girls, studying, DET_PL, ringing, looking, gone, their, i, husband, S, they, weather, show, PROPERNOUN, as, party, cows, give, having, PAST_PERFECT_CONT, started, heavily, take, FUTURE_CONT, the, listening, past, running, PAST_CONT_PL, going, has, pilot, we, constantly, flown, homework, went, before, sing, january, down, today, house, accident, waiting, player, PP, V3, new, teaching, ADJ, not, did, you, recently, whom, him, goats, turn, gave, of, meeting, lately, PAST_CONT_SG, V1_SG, last, PRES_CONT_SG, S1, well, moment, read, her, DET_SG, four, finished, weekend, PRES_PERFECT_CONT_SG, song, RELPR_SG, PRES_PERFECT_CONT_PL, FUTURE_PERFECT_CONT, around, these, seen, month, DET_BOTH, GERUNDV, NP, thinking, programming, cook, married, PRES_PERFECT_SG, PAST_PERFECT, repairing, first, this, cup, three, zoo, hungry, letter, still, next, NOUN_SG, school, no, while, few, joseph, airplane, but, plays, parcel, book, understands, always, PRES_PL, early
#
# FIRST:
#                   S' = { canada, an, patient, turkey, night, jacksons, wednesday, two, mom, every, brother, phone, boys, november, specialists, many, sister, whole, teacher, neighbourhood, topper, films, portraits, morning, children, ishwarya, severe, since, peacocks, assignment, nice, milk, terrible, years, street, grandfather, food, weeks, when, easter, cold, gracefully, never, us, mountain, evening, raj, ages, yesterday, kabaddi, america, already, mountains, wife, john, afternoon, very, germany, his, call, week, ajitesh, she, airport, whereabouts, pope, a, basketball, parents, letters, friends, navvya, football, fun, picture, paris, movie, year, friend, sentence, critical, people, ago, building, all, india, me, he, room, twice, ritheesh, may, roses, fire, sweet, bed, album, baby, my, times, emails, tomorrow, it, red, outlet, accountant, garden, dad, delicious, car, that, tea, fog, books, switzerland, girls, their, i, husband, they, weather, show, party, cows, heavily, the, past, pilot, we, constantly, homework, before, january, today, house, accident, player, new, not, you, recently, him, goats, lately, last, well, moment, her, four, weekend, song, these, month, thinking, programming, first, this, cup, three, zoo, hungry, still, letter, next, school, no, few, joseph, airplane, parcel, book, always, early }
#                    S = { canada, an, patient, turkey, night, jacksons, wednesday, two, mom, every, brother, phone, boys, november, specialists, many, sister, whole, teacher, neighbourhood, topper, films, portraits, morning, children, ishwarya, severe, since, peacocks, assignment, nice, milk, terrible, years, street, grandfather, food, weeks, when, easter, cold, gracefully, never, us, mountain, evening, raj, ages, yesterday, kabaddi, america, already, mountains, wife, john, afternoon, very, germany, his, call, week, ajitesh, she, airport, whereabouts, pope, a, basketball, parents, letters, friends, navvya, football, fun, picture, paris, movie, year, friend, sentence, critical, people, ago, building, all, india, me, he, room, twice, ritheesh, may, roses, fire, sweet, bed, album, baby, my, times, emails, tomorrow, it, red, outlet, accountant, garden, dad, delicious, car, that, tea, fog, books, switzerland, girls, their, i, husband, they, weather, show, party, cows, heavily, the, past, pilot, we, constantly, homework, before, january, today, house, accident, player, new, not, you, recently, him, goats, lately, last, well, moment, her, four, weekend, song, these, month, thinking, programming, first, this, cup, three, zoo, hungry, still, letter, next, school, no, few, joseph, airplane, parcel, book, always, early }
#                   S1 = { canada, an, patient, turkey, night, jacksons, wednesday, two, mom, every, brother, phone, boys, november, specialists, many, sister, whole, to, teacher, neighbourhood, topper, films, portraits, morning, children, ishwarya, severe, for, since, peacocks, assignment, nice, milk, terrible, years, street, grandfather, food, weeks, when, easter, cold, gracefully, never, us, at, mountain, evening, raj, ages, yesterday, kabaddi, america, already, mountains, wife, far, john, afternoon, very, germany, his, call, week, ajitesh, she, from, airport, whereabouts, pope, a, basketball, parents, letters, friends, navvya, football, fun, picture, paris, movie, year, friend, sentence, critical, people, ago, building, all, india, me, he, room, twice, by, ritheesh, may, roses, fire, sweet, bed, album, baby, my, times, emails, in, tomorrow, it, red, outlet, accountant, garden, dad, delicious, car, that, tea, fog, on, books, switzerland, girls, their, i, husband, they, weather, as, show, party, cows, heavily, the, past, pilot, we, constantly, homework, before, january, down, today, house, accident, player, new, not, you, recently, him, goats, of, lately, last, well, moment, her, four, weekend, song, around, these, month, thinking, programming, first, this, cup, three, zoo, hungry, still, letter, next, school, no, few, joseph, airplane, parcel, book, always, early }
#                   NP = { canada, an, patient, turkey, night, jacksons, wednesday, two, mom, every, brother, phone, boys, november, specialists, many, sister, whole, to, teacher, neighbourhood, topper, films, portraits, morning, children, ishwarya, severe, for, since, peacocks, assignment, nice, milk, terrible, years, street, grandfather, food, weeks, when, easter, cold, gracefully, never, us, at, mountain, evening, raj, ages, yesterday, kabaddi, america, already, mountains, wife, far, john, afternoon, very, germany, his, call, week, ajitesh, she, from, airport, whereabouts, pope, a, basketball, parents, letters, friends, navvya, football, fun, picture, paris, movie, year, friend, sentence, critical, people, ago, building, all, india, me, he, room, twice, by, ritheesh, may, roses, fire, sweet, bed, album, baby, my, times, emails, in, tomorrow, it, red, outlet, accountant, garden, dad, delicious, car, that, tea, fog, on, books, switzerland, girls, their, i, husband, they, weather, as, show, party, cows, heavily, the, past, pilot, we, constantly, homework, before, january, down, today, house, accident, player, new, not, you, recently, him, goats, of, lately, last, well, moment, her, four, weekend, song, around, these, month, thinking, programming, first, this, cup, three, zoo, hungry, still, letter, next, school, no, few, joseph, airplane, parcel, book, always, early }
#                NP_SG = { canada, an, patient, turkey, night, wednesday, two, mom, every, brother, phone, november, sister, whole, teacher, neighbourhood, topper, morning, ishwarya, severe, since, assignment, nice, milk, terrible, street, grandfather, food, when, easter, cold, gracefully, never, mountain, evening, raj, yesterday, kabaddi, america, already, wife, john, afternoon, very, germany, his, call, week, ajitesh, she, airport, whereabouts, pope, a, basketball, navvya, football, fun, picture, paris, movie, year, friend, sentence, critical, ago, building, india, me, he, room, twice, ritheesh, may, fire, sweet, bed, album, baby, my, tomorrow, it, red, outlet, accountant, garden, dad, delicious, car, that, tea, fog, switzerland, i, husband, weather, show, party, heavily, the, past, pilot, constantly, homework, before, january, today, house, accident, player, new, not, recently, him, lately, last, well, moment, her, four, weekend, song, month, thinking, programming, first, this, cup, three, zoo, hungry, still, letter, next, school, few, joseph, airplane, parcel, book, always, early }
#               NOM_SG = { patient, room, night, fire, sweet, bed, album, baby, two, mom, every, brother, red, phone, outlet, accountant, garden, sister, whole, dad, teacher, neighbourhood, delicious, topper, car, tea, fog, morning, severe, since, husband, weather, show, assignment, party, nice, milk, terrible, street, grandfather, food, cold, mountain, pilot, evening, homework, house, accident, kabaddi, player, new, wife, afternoon, last, call, week, moment, four, weekend, song, airport, pope, basketball, month, thinking, programming, football, first, fun, picture, movie, cup, three, year, friend, zoo, hungry, letter, sentence, school, critical, few, airplane, parcel, book, building, me }
#                NP_PL = { we, constantly, twice, before, jacksons, roses, sweet, ages, today, yesterday, two, times, already, emails, tomorrow, new, every, not, mountains, you, recently, red, boys, specialists, many, goats, very, whole, lately, last, delicious, well, films, portraits, four, books, children, girls, whereabouts, severe, these, since, peacocks, their, parents, letters, friends, they, first, fun, nice, cows, three, hungry, still, heavily, next, terrible, years, no, critical, few, weeks, people, ago, when, gracefully, the, never, us, all, always, past, early }
#               NOM_PL = { jacksons, roses, sweet, ages, two, times, emails, new, every, mountains, red, boys, specialists, goats, whole, last, delicious, films, portraits, four, books, children, girls, severe, since, peacocks, parents, letters, friends, first, fun, nice, cows, three, hungry, terrible, years, critical, few, weeks, people }
#                   PP = { on, from, of, by, to, around, down, for, in, far, at, as }
#                 PAST = { constantly, twice, went, made, before, knew, whereabouts, received, today, yesterday, understood, already, tomorrow, not, married, did, recently, caught, were, would, was, taught, very, started, gave, drink, still, lately, heavily, next, tired, flew, well, ago, when, read, gracefully, never, always, past, saw, early }
#         PAST_PERFECT = { had }
#         PAST_CONT_SG = { was }
#         PAST_CONT_PL = { were }
#    PAST_PERFECT_CONT = { had }
#              PRES_SG = { constantly, draws, twice, cooks, before, works, whereabouts, invloves, climbs, today, likes, yesterday, am, already, tomorrow, be, not, recently, very, is, still, lately, heavily, next, know, well, plays, teaches, ago, sings, when, gracefully, never, understands, always, past, early }
#              PRES_PL = { constantly, study, twice, before, whereabouts, do, sing, think, today, rain, yesterday, already, tomorrow, cook, not, recently, give, turn, very, go, drink, still, lately, heavily, see, next, are, speak, well, take, ago, when, gracefully, never, always, past, teach, early }
#      PRES_PERFECT_SG = { has }
#      PRES_PERFECT_PL = { have }
#         PRES_CONT_SG = { is }
#         PRES_CONT_PL = { are }
# PRES_PERFECT_CONT_SG = { has }
# PRES_PERFECT_CONT_PL = { have }
#               FUTURE = { will }
#       FUTURE_PERFECT = { will }
#          FUTURE_CONT = { will }
#  FUTURE_PERFECT_CONT = { will }
#           PRONOUN_SG = { he, him, my, i, her, it, she, his }
#           PRONOUN_PL = { us, we, they, their, you }
#             RELPR_SG = { which }
#             RELPR_PL = { whom }
#           PROPERNOUN = { november, canada, switzerland, paris, raj, turkey, ishwarya, ritheesh, may, january, germany, wednesday, joseph, ajitesh, america, easter, india, navvya, john }
#              NOUN_SG = { mountain, pilot, song, evening, homework, patient, room, airport, night, pope, basketball, fire, bed, house, album, baby, accident, kabaddi, player, month, thinking, mom, programming, husband, brother, wife, football, weather, show, phone, outlet, accountant, assignment, picture, party, movie, garden, cup, afternoon, year, friend, zoo, milk, sister, letter, dad, sentence, teacher, neighbourhood, street, grandfather, school, food, topper, call, airplane, week, moment, parcel, book, car, building, cold, tea, fog, weekend, morning, me }
#              NOUN_PL = { boys, books, cows, specialists, goats, children, girls, jacksons, roses, ages, years, films, weeks, peacocks, people, parents, times, emails, portraits, letters, friends, mountains }
#               DET_SG = { a, this, an, that }
#               DET_PL = { all, these, many, no }
#             DET_BOTH = { the }
#                 CONJ = { but, because, and, while }
#                  ADJ = { first, fun, nice, three, hungry, severe, whole, sweet, terrible, last, delicious, critical, since, few, two, four, new, every, red }
#                  ADV = { constantly, twice, very, before, whereabouts, still, lately, heavily, next, today, well, yesterday, ago, already, when, tomorrow, gracefully, never, always, past, not, recently, early }
#               PREPOS = { on, from, in, of, by, to, around, at, down, far, for, as }
#                V1_SG = { plays, draws, teaches, sings, am, cooks, works, understands, is, be, invloves, climbs, know, likes }
#                V1_PL = { rain, give, take, turn, study, go, drink, do, see, are, sing, cook, teach, think, speak }
#              GERUNDV = { climbing, visiting, repairing, burning, suffering, running, having, cleaning, studying, living, meeting, snowing, dancing, ringing, getting, playing, looking, dating, waiting, taking, enjoying, spending, raining, seeing, teaching, feeling, writing, listening, going, opening }
#                   V2 = { were, would, was, taught, went, made, knew, drink, started, gave, received, tired, flew, understood, read, married, did, saw, caught }
#                   V3 = { given, done, written, painted, flown, gone, fed, made, finished, acted, watched, met, seen }
#
# FOLLOW:
#                   S' = { $ }
#                    S = { constantly, twice, before, whereabouts, today, yesterday, already, tomorrow, not, recently, very, still, lately, heavily, next, $, well, ago, when, gracefully, never, always, past, early }
#                   S1 = { constantly, twice, before, whereabouts, today, yesterday, already, tomorrow, not, recently, very, still, lately, heavily, next, $, well, ago, when, gracefully, never, always, past, early }
#                   NP = { twice, made, by, received, likes, understood, am, in, tomorrow, had, to, teaches, and, will, teach, on, works, because, climbs, for, think, as, give, taught, started, see, heavily, flew, speak, take, sings, when, gracefully, never, past, has, at, constantly, went, before, sing, down, today, yesterday, already, be, not, did, recently, far, caught, turn, very, go, gave, drink, of, lately, $, well, read, draws, from, cooks, study, knew, whereabouts, invloves, around, do, have, rain, cook, married, were, would, was, is, still, are, next, tired, while, know, but, plays, ago, understands, always, saw, early }
#                NP_SG = { twice, made, by, received, likes, understood, am, in, tomorrow, had, to, teaches, and, will, teach, on, works, because, climbs, for, think, as, give, taught, started, see, heavily, flew, speak, take, sings, when, gracefully, never, past, has, at, constantly, went, before, sing, down, today, yesterday, already, be, not, did, recently, far, caught, turn, very, go, gave, drink, of, lately, $, well, read, draws, from, cooks, study, knew, whereabouts, invloves, around, do, have, rain, cook, married, were, would, was, is, still, are, next, tired, while, know, but, plays, ago, understands, always, saw, early }
#               NOM_SG = { patient, room, twice, made, night, by, received, fire, bed, album, likes, baby, understood, am, mom, in, tomorrow, brother, phone, outlet, accountant, garden, sister, had, dad, to, teacher, neighbourhood, topper, teaches, and, car, tea, will, fog, teach, morning, on, works, because, climbs, for, think, husband, weather, show, as, assignment, party, give, taught, milk, started, see, heavily, street, grandfather, flew, speak, food, take, sings, when, cold, gracefully, never, past, has, at, mountain, pilot, evening, constantly, homework, went, before, sing, early, down, today, house, yesterday, accident, kabaddi, player, already, be, not, wife, did, recently, far, caught, afternoon, turn, very, go, gave, drink, of, lately, $, call, well, week, moment, read, weekend, song, draws, from, cooks, airport, study, knew, whereabouts, pope, invloves, around, do, basketball, have, rain, month, thinking, programming, cook, married, football, were, would, picture, movie, was, cup, year, friend, zoo, is, still, letter, are, sentence, next, tired, while, school, know, but, airplane, plays, ago, parcel, book, building, understands, always, saw, me }
#                NP_PL = { twice, made, by, received, likes, understood, am, in, tomorrow, had, to, teaches, and, will, teach, on, works, because, think, for, climbs, as, give, taught, started, see, heavily, flew, speak, take, sings, when, gracefully, never, past, has, at, constantly, went, before, sing, down, today, yesterday, already, be, not, did, recently, far, caught, turn, very, go, gave, drink, of, lately, $, well, read, draws, study, from, cooks, knew, whereabouts, invloves, do, around, have, rain, cook, married, were, would, was, is, still, are, next, tired, while, know, but, plays, ago, understands, always, saw, early }
#               NOM_PL = { twice, made, jacksons, by, roses, received, likes, understood, am, times, emails, in, tomorrow, boys, specialists, had, to, films, teaches, and, portraits, will, teach, on, books, children, girls, works, because, think, for, climbs, peacocks, as, cows, give, taught, started, see, heavily, flew, years, speak, weeks, take, sings, when, gracefully, never, past, has, at, constantly, went, before, sing, down, ages, today, yesterday, already, be, not, mountains, did, recently, far, caught, turn, goats, very, go, gave, drink, of, lately, $, well, read, draws, study, from, cooks, knew, whereabouts, invloves, do, around, have, rain, parents, letters, friends, cook, married, were, would, was, is, still, are, next, tired, while, know, but, plays, people, ago, understands, always, saw, early }
#                   PP = { twice, made, by, received, likes, understood, am, in, tomorrow, had, to, teaches, and, will, teach, on, works, because, climbs, for, think, as, give, taught, started, see, heavily, flew, speak, take, sings, when, gracefully, never, past, has, at, constantly, went, before, sing, down, today, yesterday, already, be, not, did, recently, far, caught, turn, very, go, gave, drink, of, lately, $, well, read, draws, from, cooks, study, knew, whereabouts, invloves, around, do, have, rain, cook, married, were, would, was, is, still, are, next, tired, while, know, but, plays, ago, understands, always, saw, early }
#                 PAST = { canada, an, patient, turkey, night, jacksons, wednesday, two, mom, every, brother, phone, boys, november, specialists, many, sister, whole, to, teacher, neighbourhood, topper, films, portraits, morning, children, ishwarya, severe, for, since, peacocks, assignment, nice, milk, terrible, years, street, grandfather, food, weeks, when, easter, cold, gracefully, never, us, at, mountain, evening, raj, ages, yesterday, kabaddi, america, already, mountains, wife, far, john, afternoon, very, germany, his, call, week, ajitesh, she, from, airport, whereabouts, pope, a, basketball, parents, letters, friends, navvya, football, fun, picture, paris, movie, year, friend, sentence, critical, people, ago, building, all, india, me, he, room, twice, by, ritheesh, may, roses, fire, sweet, bed, album, baby, my, times, emails, in, tomorrow, it, red, outlet, accountant, garden, dad, delicious, car, that, tea, fog, on, books, switzerland, girls, their, i, husband, they, weather, as, show, party, cows, heavily, the, past, pilot, we, constantly, homework, before, january, down, today, house, accident, player, new, not, you, recently, him, goats, of, lately, last, well, moment, her, four, weekend, song, around, these, month, thinking, programming, first, this, cup, three, zoo, hungry, still, letter, next, school, no, few, joseph, airplane, parcel, book, always, early }
#         PAST_PERFECT = { canada, an, patient, turkey, night, jacksons, wednesday, two, mom, every, brother, phone, boys, november, specialists, many, sister, whole, to, teacher, neighbourhood, topper, films, portraits, morning, children, ishwarya, severe, for, since, peacocks, assignment, nice, milk, terrible, years, street, grandfather, food, weeks, when, easter, cold, gracefully, never, us, at, mountain, evening, raj, ages, yesterday, kabaddi, america, already, mountains, wife, far, john, afternoon, very, germany, his, call, week, ajitesh, she, from, airport, whereabouts, pope, a, basketball, parents, letters, friends, navvya, football, fun, picture, paris, movie, year, friend, sentence, critical, people, ago, building, all, india, me, he, room, twice, by, ritheesh, may, roses, fire, sweet, bed, album, baby, my, times, emails, in, tomorrow, it, red, outlet, accountant, garden, dad, delicious, car, that, tea, fog, on, books, switzerland, girls, their, i, husband, they, weather, as, show, party, cows, heavily, the, past, pilot, we, constantly, homework, before, january, down, today, house, accident, player, new, not, you, recently, him, goats, of, lately, last, well, moment, her, four, weekend, song, around, these, month, thinking, programming, first, this, cup, three, zoo, hungry, still, letter, next, school, no, few, joseph, airplane, parcel, book, always, early }
#         PAST_CONT_SG = { canada, an, patient, turkey, night, jacksons, wednesday, two, mom, every, brother, phone, boys, november, specialists, many, sister, whole, to, teacher, neighbourhood, topper, films, portraits, morning, children, ishwarya, severe, for, since, peacocks, assignment, nice, milk, terrible, years, street, grandfather, food, weeks, when, easter, cold, gracefully, never, us, at, mountain, evening, raj, ages, yesterday, kabaddi, america, already, mountains, wife, far, john, afternoon, very, germany, his, call, week, ajitesh, she, from, airport, whereabouts, pope, a, basketball, parents, letters, friends, navvya, football, fun, picture, paris, movie, year, friend, sentence, critical, people, ago, building, all, india, me, he, room, twice, by, ritheesh, may, roses, fire, sweet, bed, album, baby, my, times, emails, in, tomorrow, it, red, outlet, accountant, garden, dad, delicious, car, that, tea, fog, on, books, switzerland, girls, their, i, husband, they, weather, as, show, party, cows, heavily, the, past, pilot, we, constantly, homework, before, january, down, today, house, accident, player, new, not, you, recently, him, goats, of, lately, last, well, moment, her, four, weekend, song, around, these, month, thinking, programming, first, this, cup, three, zoo, hungry, still, letter, next, school, no, few, joseph, airplane, parcel, book, always, early }
#         PAST_CONT_PL = { canada, an, patient, turkey, night, jacksons, wednesday, two, mom, every, brother, phone, boys, november, specialists, many, sister, whole, to, teacher, neighbourhood, topper, films, portraits, morning, children, ishwarya, severe, for, since, peacocks, assignment, nice, milk, terrible, years, street, grandfather, food, weeks, when, easter, cold, gracefully, never, us, at, mountain, evening, raj, ages, yesterday, kabaddi, america, already, mountains, wife, far, john, afternoon, very, germany, his, call, week, ajitesh, she, from, airport, whereabouts, pope, a, basketball, parents, letters, friends, navvya, football, fun, picture, paris, movie, year, friend, sentence, critical, people, ago, building, all, india, me, he, room, twice, by, ritheesh, may, roses, fire, sweet, bed, album, baby, my, times, emails, in, tomorrow, it, red, outlet, accountant, garden, dad, delicious, car, that, tea, fog, on, books, switzerland, girls, their, i, husband, they, weather, as, show, party, cows, heavily, the, past, pilot, we, constantly, homework, before, january, down, today, house, accident, player, new, not, you, recently, him, goats, of, lately, last, well, moment, her, four, weekend, song, around, these, month, thinking, programming, first, this, cup, three, zoo, hungry, still, letter, next, school, no, few, joseph, airplane, parcel, book, always, early }
#    PAST_PERFECT_CONT = { canada, an, patient, turkey, night, jacksons, wednesday, two, mom, every, brother, phone, boys, november, specialists, many, sister, whole, to, teacher, neighbourhood, topper, films, portraits, morning, children, ishwarya, severe, for, since, peacocks, assignment, nice, milk, terrible, years, street, grandfather, food, weeks, when, easter, cold, gracefully, never, us, at, mountain, evening, raj, ages, yesterday, kabaddi, america, already, mountains, wife, far, john, afternoon, very, germany, his, call, week, ajitesh, she, from, airport, whereabouts, pope, a, basketball, parents, letters, friends, navvya, football, fun, picture, paris, movie, year, friend, sentence, critical, people, ago, building, all, india, me, he, room, twice, by, ritheesh, may, roses, fire, sweet, bed, album, baby, my, times, emails, in, tomorrow, it, red, outlet, accountant, garden, dad, delicious, car, that, tea, fog, on, books, switzerland, girls, their, i, husband, they, weather, as, show, party, cows, heavily, the, past, pilot, we, constantly, homework, before, january, down, today, house, accident, player, new, not, you, recently, him, goats, of, lately, last, well, moment, her, four, weekend, song, around, these, month, thinking, programming, first, this, cup, three, zoo, hungry, still, letter, next, school, no, few, joseph, airplane, parcel, book, always, early }
#              PRES_SG = { canada, an, patient, turkey, night, jacksons, wednesday, two, mom, every, brother, phone, boys, november, specialists, many, sister, whole, to, teacher, neighbourhood, topper, films, portraits, morning, children, ishwarya, severe, for, since, peacocks, assignment, nice, milk, terrible, years, street, grandfather, food, weeks, when, easter, cold, gracefully, never, us, at, mountain, evening, raj, ages, yesterday, kabaddi, america, already, mountains, wife, far, john, afternoon, very, germany, his, call, week, ajitesh, she, from, airport, whereabouts, pope, a, basketball, parents, letters, friends, navvya, football, fun, picture, paris, movie, year, friend, sentence, critical, people, ago, building, all, india, me, he, room, twice, by, ritheesh, may, roses, fire, sweet, bed, album, baby, my, times, emails, in, tomorrow, it, red, outlet, accountant, garden, dad, delicious, car, that, tea, fog, on, books, switzerland, girls, their, i, husband, they, weather, as, show, party, cows, heavily, the, past, pilot, we, constantly, homework, before, january, down, today, house, accident, player, new, not, you, recently, him, goats, of, lately, last, well, moment, her, four, weekend, song, around, these, month, thinking, programming, first, this, cup, three, zoo, hungry, still, letter, next, school, no, few, joseph, airplane, parcel, book, always, early }
#              PRES_PL = { canada, an, patient, turkey, night, jacksons, wednesday, two, mom, every, brother, phone, boys, november, specialists, many, sister, whole, to, teacher, neighbourhood, topper, films, portraits, morning, children, ishwarya, severe, for, since, peacocks, assignment, nice, milk, terrible, years, street, grandfather, food, weeks, when, easter, cold, gracefully, never, us, at, mountain, evening, raj, ages, yesterday, kabaddi, america, already, mountains, wife, far, john, afternoon, very, germany, his, call, week, ajitesh, she, from, airport, whereabouts, pope, a, basketball, parents, letters, friends, navvya, football, fun, picture, paris, movie, year, friend, sentence, critical, people, ago, building, all, india, me, he, room, twice, by, ritheesh, may, roses, fire, sweet, bed, album, baby, my, times, emails, in, tomorrow, it, red, outlet, accountant, garden, dad, delicious, car, that, tea, fog, on, books, switzerland, girls, their, i, husband, they, weather, as, show, party, cows, heavily, the, past, pilot, we, constantly, homework, before, january, down, today, house, accident, player, new, not, you, recently, him, goats, of, lately, last, well, moment, her, four, weekend, song, around, these, month, thinking, programming, first, this, cup, three, zoo, hungry, still, letter, next, school, no, few, joseph, airplane, parcel, book, always, early }
#      PRES_PERFECT_SG = { canada, an, patient, turkey, night, jacksons, wednesday, two, mom, every, brother, phone, boys, november, specialists, many, sister, whole, to, teacher, neighbourhood, topper, films, portraits, morning, children, ishwarya, severe, for, since, peacocks, assignment, nice, milk, terrible, years, street, grandfather, food, weeks, when, easter, cold, gracefully, never, us, at, mountain, evening, raj, ages, yesterday, kabaddi, america, already, mountains, wife, far, john, afternoon, very, germany, his, call, week, ajitesh, she, from, airport, whereabouts, pope, a, basketball, parents, letters, friends, navvya, football, fun, picture, paris, movie, year, friend, sentence, critical, people, ago, building, all, india, me, he, room, twice, by, ritheesh, may, roses, fire, sweet, bed, album, baby, my, times, emails, in, tomorrow, it, red, outlet, accountant, garden, dad, delicious, car, that, tea, fog, on, books, switzerland, girls, their, i, husband, they, weather, as, show, party, cows, heavily, the, past, pilot, we, constantly, homework, before, january, down, today, house, accident, player, new, not, you, recently, him, goats, of, lately, last, well, moment, her, four, weekend, song, around, these, month, thinking, programming, first, this, cup, three, zoo, hungry, still, letter, next, school, no, few, joseph, airplane, parcel, book, always, early }
# ...
# |         437          |          r82         |          r82         |          r82         |          r82         |          r82         |          r82         |          r82         |                      |          r82         |          r82         |          r82         |          r82         |          r82         |          r82         |                      |          r82         |          r82         |          r82         |          r82         |                      |          r82         |          r82         |                      |                      |          r82         |                      |          r82         |          r82         |          r82         |          r82         |          r82         |          r82         |          r82         |          r82         |          r82         |          r82         |          r82         |          r82         |          r82         |          r82         |          r82         |          r82         |          r82         |          r82         |          r82         |                      |                      |          r82         |          r82         |          r82         |          r82         |                      |          r82         |          r82         |                      |          r82         |          r82         |                      |                      |                      |          r82         |                      |          r82         |          r82         |          r82         |                      |          r82         |                      |          r82         |                      |                      |          r82         |          r82         |          r82         |          r82         |          r82         |                      |                      |          r82         |          r82         |                      |                      |          r82         |                      |          r82         |                      |          r82         |                      |                      |          r82         |          r82         |          r82         |                      |          r82         |          r82         |          r82         |          r82         |          r82         |          r82         |          r82         |          r82         |                      |                      |                      |                      |                      |          r82         |                      |                      |          r82         |          r82         |          r82         |          r82         |          r82         |          r82         |                      |                      |          r82         |                      |                      |          r82         |          r82         |          r82         |          r82         |          r82         |          r82         |          r82         |                      |          r82         |                      |                      |                      |          r82         |                      |          r82         |          r82         |          r82         |          r82         |          r82         |                      |          r82         |          r82         |                      |          r82         |                      |          r82         |          r82         |          r82         |          r82         |          r82         |          r82         |                      |          r82         |          r82         |                      |          r82         |                      |                      |          r82         |          r82         |          r82         |                      |                      |                      |          r82         |                      |          r82         |          r82         |          r82         |          r82         |          r82         |          r82         |                     ...
# |         438          |          r90         |          r90         |          r90         |          r90         |          r90         |          r90         |          r90         |                      |          r90         |          r90         |          r90         |          r90         |          r90         |          r90         |                      |          r90         |          r90         |          r90         |          r90         |                      |          r90         |          r90         |                      |                      |          r90         |                      |          r90         |          r90         |          r90         |          r90         |          r90         |          r90         |          r90         |          r90         |          r90         |          r90         |          r90         |          r90         |          r90         |          r90         |          r90         |          r90         |          r90         |          r90         |          r90         |                      |                      |          r90         |          r90         |          r90         |          r90         |                      |          r90         |          r90         |                      |          r90         |          r90         |                      |                      |                      |          r90         |                      |          r90         |          r90         |          r90         |                      |          r90         |                      |          r90         |                      |                      |          r90         |          r90         |          r90         |          r90         |          r90         |                      |                      |          r90         |          r90         |                      |                      |          r90         |                      |          r90         |                      |          r90         |                      |                      |          r90         |          r90         |          r90         |                      |          r90         |          r90         |          r90         |          r90         |          r90         |          r90         |          r90         |          r90         |                      |                      |                      |                      |                      |          r90         |                      |                      |          r90         |          r90         |          r90         |          r90         |          r90         |          r90         |                      |                      |          r90         |                      |                      |          r90         |          r90         |          r90         |          r90         |          r90         |          r90         |          r90         |                      |          r90         |                      |                      |                      |          r90         |                      |          r90         |          r90         |          r90         |          r90         |          r90         |                      |          r90         |          r90         |                      |          r90         |                      |          r90         |          r90         |          r90         |          r90         |          r90         |          r90         |                      |          r90         |          r90         |                      |          r90         |                      |                      |          r90         |          r90         |          r90         |                      |                      |                      |          r90         |                      |          r90         |          r90         |          r90         |          r90         |          r90         |          r90         |                     ...
# +----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+-------------------- ...

# %% [markdown]
# ## Text Pre-processing

# %%
# READING INPUT FROM FILE

inputFile = open('input.txt', 'r')
inputText = inputFile.read()
text = inputText.replace('\n', ' ')
inputFile.close()
text
# Out:
# 'She were writing a letter to Ishwarya. My teacher teaches well. She went to school. Raj is climbs a mountian. Raj plays fotball well. Mom cook delisious food. Navvya is a topper. Ishwarya is a kabbadi player. Ishwarya will sings a song in the show. These people is from Canada.'

# %%
# OUTPUT REPORT

outputLines = []
outputLines.append("ANALYSIS REPORT : \n\n")
outputLines.append("---------------------------------------------\n\n")

# %%
# SENTENCE TOKENIZATION

stop_Char=["!",".","?",";"]

sentences=[]

sentence=""
for ch in text :
  if ch not in stop_Char:
    sentence += ch
  else :
    sentence = sentence.strip()
    sentences.append(sentence)
    sentence=""  

sentenceCount = len(sentences) 
print("Sentence count : " + str(sentenceCount))

for sentence in sentences :
  print(sentence)
# Out:
# Sentence count : 10
# She were writing a letter to Ishwarya
# My teacher teaches well
# She went to school
# Raj is climbs a mountian
# Raj plays fotball well
# Mom cook delisious food
# Navvya is a topper
# Ishwarya is a kabbadi player
# Ishwarya will sings a song in the show
# These people is from Canada

# %%
# REMOVAL OF STOP CHARACTERS

reqSplChars = ["@", "&", "(", ")", "-"]
splChars = ["#", "%", "&", "^", "$", "*", "`", "+"]
punctuation = [",", ".", "!"]

exclude = splChars + punctuation
cleanSentences=[]
for sentence in sentences :
  cleantext=""
  for ch in sentence :
    if ch not in exclude:
      cleantext += ch
  cleanSentences.append(cleantext)

for cleanSentence in cleanSentences :
  print(cleanSentence)
# Out:
# She were writing a letter to Ishwarya
# My teacher teaches well
# She went to school
# Raj is climbs a mountian
# Raj plays fotball well
# Mom cook delisious food
# Navvya is a topper
# Ishwarya is a kabbadi player
# Ishwarya will sings a song in the show
# These people is from Canada

# %%
# WORD TOKENIZATION

wordsArray = []
wordsCount = []
for cleanText in cleanSentences :
  words = []
  word = ""
  i = 0
  while(i < len(cleanText)):
    if(cleanText[i] == " "):
      i += 1
    else:
      word = ""
      while(i < len(cleanText) and cleanText[i] != " "):
        word += cleanText[i]
        i += 1
      if(len(word) > 0):
        words.append(word)
  wordsArray.append(words)
  wordsCount.append(len(words))

totalWordCount = sum(wordsCount)

for i in range(sentenceCount) :
  print(wordsArray[i])
  print("Word count : " + str(wordsCount[i]))
  print()

print("Total word count : " + str(totalWordCount))
# Out:
# ['She', 'were', 'writing', 'a', 'letter', 'to', 'Ishwarya']
# Word count : 7
#
# ['My', 'teacher', 'teaches', 'well']
# Word count : 4
#
# ['She', 'went', 'to', 'school']
# Word count : 4
#
# ['Raj', 'is', 'climbs', 'a', 'mountian']
# Word count : 5
#
# ['Raj', 'plays', 'fotball', 'well']
# Word count : 4
#
# ['Mom', 'cook', 'delisious', 'food']
# Word count : 4
#
# ['Navvya', 'is', 'a', 'topper']
# Word count : 4
#
# ['Ishwarya', 'is', 'a', 'kabbadi', 'player']
# Word count : 5
#
# ['Ishwarya', 'will', 'sings', 'a', 'song', 'in', 'the', 'show']
# Word count : 8
#
# ['These', 'people', 'is', 'from', 'Canada']
# Word count : 5
#
# Total word count : 50

# %%
# Spell Check

spell = SpellChecker()

correctedWordsArray = []
misspelledCount = []
misspelledResult = []
for words in wordsArray : 
  count = 0
  misspelled = spell.unknown(words)
  
  if(len(misspelled) > 0):
    print(words)
    for word in misspelled:
        if(word not in properNouns) :
          count += 1
          print("Word : " + word)
          print("Best match : " + str(spell.correction(word)))
          print("Possible matches : " + str(spell.candidates(word)))
          misspelledResult.append("Misspelled word : {}\nBest match : {}\nPossible matches : {}\n\n".format(word, str(spell.correction(word)), str(spell.candidates(word))))
    print("Misspelled word count : " + str(count))
    misspelledCount.append(count)
    print()
    
    # Correcting the misspelled words
    correctedWords = []
    for word in words :
      if word in misspelled :
        correctedWords.append((spell.correction(word)).lower())
      else :
        correctedWords.append(word.lower())
    correctedWordsArray.append(correctedWords)
  else :
    correctedWords = [word.lower() for word in words]
    correctedWordsArray.append(correctedWords)
    print(words)
    print("Misspelled word count : " + str(len(misspelled)))
    print()
# Out:
# ['She', 'were', 'writing', 'a', 'letter', 'to', 'Ishwarya']
# Misspelled word count : 0
#
# ['My', 'teacher', 'teaches', 'well']
# Misspelled word count : 0
#
# ['She', 'went', 'to', 'school']
# Misspelled word count : 0
#
# ['Raj', 'is', 'climbs', 'a', 'mountian']
# Word : mountian
# Best match : mountain
# Possible matches : {'mountain'}
# Misspelled word count : 1
#
# ['Raj', 'plays', 'fotball', 'well']
# Word : fotball
# Best match : football
# Possible matches : {'football', 'fooball', 'ootball'}
# Misspelled word count : 1
#
# ['Mom', 'cook', 'delisious', 'food']
# Word : delisious
# Best match : delicious
# Possible matches : {'delicious', 'delirious'}
# Misspelled word count : 1
#
# ['Navvya', 'is', 'a', 'topper']
# Misspelled word count : 0
#
# ['Ishwarya', 'is', 'a', 'kabbadi', 'player']
# Word : kabbadi
# Best match : kabaddi
# Possible matches : {'kabaddi'}
# Misspelled word count : 1
#
# ['Ishwarya', 'will', 'sings', 'a', 'song', 'in', 'the', 'show']
# Misspelled word count : 0
#
# ['These', 'people', 'is', 'from', 'Canada']
# Misspelled word count : 0

# %%
totalMispelledCount = sum(misspelledCount)
print("Total misspelled words : " + str(totalMispelledCount))

print("Array of words with correct spelling : ")
for words in correctedWordsArray :
  print(words)
# Out:
# Total misspelled words : 4
# Array of words with correct spelling :
# ['she', 'were', 'writing', 'a', 'letter', 'to', 'ishwarya']
# ['my', 'teacher', 'teaches', 'well']
# ['she', 'went', 'to', 'school']
# ['raj', 'is', 'climbs', 'a', 'mountain']
# ['raj', 'plays', 'football', 'well']
# ['mom', 'cook', 'delicious', 'food']
# ['navvya', 'is', 'a', 'topper']
# ['ishwarya', 'is', 'a', 'kabaddi', 'player']
# ['ishwarya', 'will', 'sings', 'a', 'song', 'in', 'the', 'show']
# ['these', 'people', 'is', 'from', 'canada']

# %%
outputLines.append("Sentence Count : {}\n".format(sentenceCount))
outputLines.append("Word Count : {}\n".format(totalWordCount))
outputLines.append("Misspelled Count : {}\n\n".format(totalMispelledCount))
outputLines.append("---------------------------------------------\n\n")
for result in misspelledResult :
  outputLines.append(result)
outputLines.append("---------------------------------------------\n\n")

# %% [markdown]
# ## Evaluation of Grammar Correctness
#
# Input : SLR(1) Parsing table, input sentences
#
# Output : Analysis report of the input
#
#
# -> Stack immplementation of input sentence
#
# -> Semantic analysis using NLP
#
# -> Genration of report

# %%
# Stack implementaion of input strings

def LR_parser(slr, w):
  isAccepted = False
  buffer = [x for x in w]
  buffer.append('$')
  pointer = 0
  a = buffer[pointer]
  stack = ['0']
  symbols = ['']
  results = {'step': [''], 'stack': ['STACK'] + stack, 'symbols': ['SYMBOLS'] + symbols, 'input': ['INPUT'], 'action': ['ACTION']}

  step = 0
  while True:
    s = int(stack[-1])
    step += 1
    results['step'].append(f'({step})')
    results['input'].append(' '.join(buffer[pointer:]))

    if a not in slr.parse_table[s]:
      results['action'].append(f'ERROR: unrecognized symbol {a}')
      isAccepted = False
      break

    elif not slr.parse_table[s][a]:
      results['action'].append('ERROR: input cannot be parsed by given grammar')
      isAccepted = False
      break

    elif '/' in slr.parse_table[s][a]:
      action = 'reduce' if slr.parse_table[s][a].count('r') > 1 else 'shift'
      results['action'].append(f'ERROR: {action}-reduce conflict at state {s}, symbol {a}')
      isAccepted = False
      break

    elif slr.parse_table[s][a].startswith('s'):
      results['action'].append('shift')
      stack.append(slr.parse_table[s][a][1:])
      symbols.append(a)
      results['stack'].append(' '.join(stack))
      results['symbols'].append(' '.join(symbols))
      pointer += 1
      a = buffer[pointer]

    elif slr.parse_table[s][a].startswith('r'):
      head, body = slr.G_indexed[int(slr.parse_table[s][a][1:])]
      results['action'].append(f'reduce by {head} -> {" ".join(body)}')

      if body != ('^',):
        stack = stack[:-len(body)]
        symbols = symbols[:-len(body)]

      stack.append(str(slr.parse_table[int(stack[-1])][head]))
      symbols.append(head)
      results['stack'].append(' '.join(stack))
      results['symbols'].append(' '.join(symbols))

    elif slr.parse_table[s][a] == 'acc':
      results['action'].append('accept')
      isAccepted = True
      break

  # Printing results
  def print_line():
    print(f'{"".join(["+" + ("-" * (max_len + 2)) for max_len in max_lens.values()])}+')

  max_lens = {key: max(len(value) for value in results[key]) for key in results}
  justs = {'step': '>', 'stack': '', 'symbols': '', 'input': '>', 'action': ''}

  print_line()
  print(''.join([f'| {history[0]:^{max_len}} ' for history, max_len in zip(results.values(), max_lens.values())]) + '|')
  print_line()
  for i, step in enumerate(results['step'][:-1], 1):
    print(''.join([f'| {history[i]:{just}{max_len}} ' for history, just, max_len in zip(results.values(), justs.values(), max_lens.values())]) + '|')

  print_line()

  return isAccepted

# %%
incorrectSentenceCount = 0
incorrectSentenceResult = []
for input_text in correctedWordsArray :
  isAccepted = LR_parser(slr, input_text)
  # Performing semantic analysis  using nlp for grammar corrections
  if(not isAccepted) :
    print("Correction : ")
    correction = GingerIt().parse(" ".join(input_text))['result']
    print(correction)
    incorrectSentenceCount += 1
    incorrectSentenceResult.append("Incorrect sentence : {}\nCorrection : {}\n\n".format(" ".join(input_text), correction))
# Out:
# +-----+---------+-------------+-----------------------------------------+------------------------------------------------+
# |     |  STACK  |   SYMBOLS   |                  INPUT                  |                     ACTION                     |
# +-----+---------+-------------+-----------------------------------------+------------------------------------------------+
# | (1) | 0       |             | she were writing a letter to ishwarya $ | shift                                          |
# | (2) | 0 67    |  she        |     were writing a letter to ishwarya $ | reduce by PRONOUN_SG -> she                    |
# | (3) | 0 48    |  PRONOUN_SG |     were writing a letter to ishwarya $ | reduce by NP_SG -> PRONOUN_SG                  |
# | (4) | 0 9     |  NP_SG      |     were writing a letter to ishwarya $ | shift                                          |
# | (5) | 0 9 214 |  NP_SG were |          writing a letter to ishwarya $ | ERROR: input cannot be parsed by given grammar |
# +-----+---------+-------------+-----------------------------------------+------------------------------------------------+
# Correction :
# she was writing a letter to ishwarya
# +------+-------------+---------------------+---------------------------+--------------------------------------+
# |      |    STACK    |       SYMBOLS       |           INPUT           |                ACTION                |
# +------+-------------+---------------------+---------------------------+--------------------------------------+
# |  (1) | 0           |                     | my teacher teaches well $ | shift                                |
# |  (2) | 0 106       |  my                 |    teacher teaches well $ | reduce by PRONOUN_SG -> my           |
# |  (3) | 0 48        |  PRONOUN_SG         |    teacher teaches well $ | shift                                |
# |  (4) | 0 48 20     |  PRONOUN_SG teacher |            teaches well $ | reduce by NOUN_SG -> teacher         |
# |  (5) | 0 48 179    |  PRONOUN_SG NOUN_SG |            teaches well $ | reduce by NOM_SG -> NOUN_SG          |
# |  (6) | 0 48 279    |  PRONOUN_SG NOM_SG  |            teaches well $ | reduce by NP_SG -> PRONOUN_SG NOM_SG |
# |  (7) | 0 9         |  NP_SG              |            teaches well $ | shift                                |
# |  (8) | 0 9 223     |  NP_SG teaches      |                    well $ | reduce by V1_SG -> teaches           |
# |  (9) | 0 9 233     |  NP_SG V1_SG        |                    well $ | reduce by PRES_SG -> V1_SG           |
# | (10) | 0 9 196     |  NP_SG PRES_SG      |                    well $ | shift                                |
# | (11) | 0 9 196 158 |  NP_SG PRES_SG well |                         $ | reduce by ADV -> well                |
# | (12) | 0 9 196 328 |  NP_SG PRES_SG ADV  |                         $ | reduce by S1 -> ADV                  |
# | (13) | 0 9 196 329 |  NP_SG PRES_SG S1   |                         $ | reduce by S -> NP_SG PRES_SG S1      |
# | (14) | 0 129       |  S                  |                         $ | accept                               |
# +------+-------------+---------------------+---------------------------+--------------------------------------+
# +------+-----------------+----------------------------+----------------------+-------------------------------+
# |      |      STACK      |          SYMBOLS           |        INPUT         |            ACTION             |
# +------+-----------------+----------------------------+----------------------+-------------------------------+
# |  (1) | 0               |                            | she went to school $ | shift                         |
# |  (2) | 0 67            |  she                       |     went to school $ | reduce by PRONOUN_SG -> she   |
# |  (3) | 0 48            |  PRONOUN_SG                |     went to school $ | reduce by NP_SG -> PRONOUN_SG |
# |  (4) | 0 9             |  NP_SG                     |     went to school $ | shift                         |
# |  (5) | 0 9 229         |  NP_SG went                |          to school $ | reduce by V2 -> went          |
# |  (6) | 0 9 202         |  NP_SG V2                  |          to school $ | reduce by PAST -> V2          |
# |  (7) | 0 9 209         |  NP_SG PAST                |          to school $ | shift                         |
# |  (8) | 0 9 209 297     |  NP_SG PAST to             |             school $ | reduce by PREPOS -> to        |
# |  (9) | 0 9 209 296     |  NP_SG PAST PREPOS         |             school $ | shift                         |
# | (10) | 0 9 209 296 180 |  NP_SG PAST PREPOS school  |                    $ | reduce by NOUN_SG -> school   |
# | (11) | 0 9 209 296 179 |  NP_SG PAST PREPOS NOUN_SG |                    $ | reduce by NOM_SG -> NOUN_SG   |
# | (12) | 0 9 209 296 34  |  NP_SG PAST PREPOS NOM_SG  |                    $ | reduce by NP_SG -> NOM_SG     |
# | (13) | 0 9 209 296 409 |  NP_SG PAST PREPOS NP_SG   |                    $ | reduce by PP -> PREPOS NP_SG  |
# | (14) | 0 9 209 308     |  NP_SG PAST PP             |                    $ | reduce by NP -> PP            |
# | (15) | 0 9 209 330     |  NP_SG PAST NP             |                    $ | reduce by S1 -> NP            |
# | (16) | 0 9 209 332     |  NP_SG PAST S1             |                    $ | reduce by S -> NP_SG PAST S1  |
# | (17) | 0 129           |  S                         |                    $ | accept                        |
# +------+-----------------+----------------------------+----------------------+-------------------------------+
# +-----+---------+-------------+----------------------------+------------------------------------------------+
# |     |  STACK  |   SYMBOLS   |           INPUT            |                     ACTION                     |
# +-----+---------+-------------+----------------------------+------------------------------------------------+
# | (1) | 0       |             | raj is climbs a mountain $ | shift                                          |
# | (2) | 0 51    |  raj        |     is climbs a mountain $ | reduce by PROPERNOUN -> raj                    |
# | (3) | 0 133   |  PROPERNOUN |     is climbs a mountain $ | reduce by NP_SG -> PROPERNOUN                  |
# | (4) | 0 9     |  NP_SG      |     is climbs a mountain $ | shift                                          |
# | (5) | 0 9 217 |  NP_SG is   |        climbs a mountain $ | ERROR: input cannot be parsed by given grammar |
# +-----+---------+-------------+----------------------------+------------------------------------------------+
# Correction :
# raj climbs a mountain
# +------+-------------+-------------------------+---------------------------+---------------------------------+
# |      |    STACK    |         SYMBOLS         |           INPUT           |             ACTION              |
# +------+-------------+-------------------------+---------------------------+---------------------------------+
# |  (1) | 0           |                         | raj plays football well $ | shift                           |
# |  (2) | 0 51        |  raj                    |     plays football well $ | reduce by PROPERNOUN -> raj     |
# |  (3) | 0 133       |  PROPERNOUN             |     plays football well $ | reduce by NP_SG -> PROPERNOUN   |
# |  (4) | 0 9         |  NP_SG                  |     plays football well $ | shift                           |
# |  (5) | 0 9 243     |  NP_SG plays            |           football well $ | reduce by V1_SG -> plays        |
# |  (6) | 0 9 233     |  NP_SG V1_SG            |           football well $ | reduce by PRES_SG -> V1_SG      |
# |  (7) | 0 9 196     |  NP_SG PRES_SG          |           football well $ | shift                           |
# |  (8) | 0 9 196 78  |  NP_SG PRES_SG football |                    well $ | reduce by NOUN_SG -> football   |
# |  (9) | 0 9 196 179 |  NP_SG PRES_SG NOUN_SG  |                    well $ | reduce by NOM_SG -> NOUN_SG     |
# | (10) | 0 9 196 34  |  NP_SG PRES_SG NOM_SG   |                    well $ | reduce by NP_SG -> NOM_SG       |
# | (11) | 0 9 196 295 |  NP_SG PRES_SG NP_SG    |                    well $ | reduce by NP -> NP_SG           |
# | (12) | 0 9 196 330 |  NP_SG PRES_SG NP       |                    well $ | reduce by S1 -> NP              |
# | (13) | 0 9 196 329 |  NP_SG PRES_SG S1       |                    well $ | reduce by S -> NP_SG PRES_SG S1 |
# | (14) | 0 129       |  S                      |                    well $ | shift                           |
# | (15) | 0 129 158   |  S well                 |                         $ | reduce by ADV -> well           |
# | (16) | 0 129 289   |  S ADV                  |                         $ | reduce by S -> S ADV            |
# | (17) | 0 129       |  S                      |                         $ | accept                          |
# +------+-------------+-------------------------+---------------------------+---------------------------------+
# +-----+-------+----------+---------------------------+------------------------------------------------+
# |     | STACK | SYMBOLS  |           INPUT           |                     ACTION                     |
# +-----+-------+----------+---------------------------+------------------------------------------------+
# | (1) | 0     |          | mom cook delicious food $ | shift                                          |
# | (2) | 0 10  |  mom     |     cook delicious food $ | reduce by NOUN_SG -> mom                       |
# | (3) | 0 179 |  NOUN_SG |     cook delicious food $ | reduce by NOM_SG -> NOUN_SG                    |
# | (4) | 0 34  |  NOM_SG  |     cook delicious food $ | reduce by NP_SG -> NOM_SG                      |
# | (5) | 0 9   |  NP_SG   |     cook delicious food $ | ERROR: input cannot be parsed by given grammar |
# +-----+-------+----------+---------------------------+------------------------------------------------+
# Correction :
# mom cooks delicious food
# +------+-----------------+-------------------------------+----------------------+----------------------------------+
# |      |      STACK      |            SYMBOLS            |        INPUT         |              ACTION              |
# +------+-----------------+-------------------------------+----------------------+----------------------------------+
# |  (1) | 0               |                               | navvya is a topper $ | shift                            |
# |  (2) | 0 77            |  navvya                       |        is a topper $ | reduce by PROPERNOUN -> navvya   |
# |  (3) | 0 133           |  PROPERNOUN                   |        is a topper $ | reduce by NP_SG -> PROPERNOUN    |
# |  (4) | 0 9             |  NP_SG                        |        is a topper $ | shift                            |
# |  (5) | 0 9 217         |  NP_SG is                     |           a topper $ | reduce by V1_SG -> is            |
# |  (6) | 0 9 233         |  NP_SG V1_SG                  |           a topper $ | reduce by PRES_SG -> V1_SG       |
# |  (7) | 0 9 196         |  NP_SG PRES_SG                |           a topper $ | shift                            |
# |  (8) | 0 9 196 71      |  NP_SG PRES_SG a              |             topper $ | reduce by DET_SG -> a            |
# |  (9) | 0 9 196 161     |  NP_SG PRES_SG DET_SG         |             topper $ | shift                            |
# | (10) | 0 9 196 161 22  |  NP_SG PRES_SG DET_SG topper  |                    $ | reduce by NOUN_SG -> topper      |
# | (11) | 0 9 196 161 179 |  NP_SG PRES_SG DET_SG NOUN_SG |                    $ | reduce by NOM_SG -> NOUN_SG      |
# | (12) | 0 9 196 161 292 |  NP_SG PRES_SG DET_SG NOM_SG  |                    $ | reduce by NP_SG -> DET_SG NOM_SG |
# | (13) | 0 9 196 295     |  NP_SG PRES_SG NP_SG          |                    $ | reduce by NP -> NP_SG            |
# | (14) | 0 9 196 330     |  NP_SG PRES_SG NP             |                    $ | reduce by S1 -> NP               |
# | (15) | 0 9 196 329     |  NP_SG PRES_SG S1             |                    $ | reduce by S -> NP_SG PRES_SG S1  |
# | (16) | 0 129           |  S                            |                    $ | accept                           |
# +------+-----------------+-------------------------------+----------------------+----------------------------------+
# +------+---------------------+--------------------------------------+--------------------------------+------------------------------------+
# |      |        STACK        |               SYMBOLS                |             INPUT              |               ACTION               |
# +------+---------------------+--------------------------------------+--------------------------------+------------------------------------+
# |  (1) | 0                   |                                      | ishwarya is a kabaddi player $ | shift                              |
# |  (2) | 0 28                |  ishwarya                            |          is a kabaddi player $ | reduce by PROPERNOUN -> ishwarya   |
# |  (3) | 0 133               |  PROPERNOUN                          |          is a kabaddi player $ | reduce by NP_SG -> PROPERNOUN      |
# |  (4) | 0 9                 |  NP_SG                               |          is a kabaddi player $ | shift                              |
# |  (5) | 0 9 217             |  NP_SG is                            |             a kabaddi player $ | reduce by V1_SG -> is              |
# |  (6) | 0 9 233             |  NP_SG V1_SG                         |             a kabaddi player $ | reduce by PRES_SG -> V1_SG         |
# |  (7) | 0 9 196             |  NP_SG PRES_SG                       |             a kabaddi player $ | shift                              |
# |  (8) | 0 9 196 71          |  NP_SG PRES_SG a                     |               kabaddi player $ | reduce by DET_SG -> a              |
# |  (9) | 0 9 196 161         |  NP_SG PRES_SG DET_SG                |               kabaddi player $ | shift                              |
# | (10) | 0 9 196 161 54      |  NP_SG PRES_SG DET_SG kabaddi        |                       player $ | reduce by NOUN_SG -> kabaddi       |
# | (11) | 0 9 196 161 179     |  NP_SG PRES_SG DET_SG NOUN_SG        |                       player $ | reduce by NOM_SG -> NOUN_SG        |
# | (12) | 0 9 196 161 292     |  NP_SG PRES_SG DET_SG NOM_SG         |                       player $ | shift                              |
# | (13) | 0 9 196 161 292 148 |  NP_SG PRES_SG DET_SG NOM_SG player  |                              $ | reduce by NOUN_SG -> player        |
# | (14) | 0 9 196 161 292 278 |  NP_SG PRES_SG DET_SG NOM_SG NOUN_SG |                              $ | reduce by NOM_SG -> NOM_SG NOUN_SG |
# | (15) | 0 9 196 161 292     |  NP_SG PRES_SG DET_SG NOM_SG         |                              $ | reduce by NP_SG -> DET_SG NOM_SG   |
# | (16) | 0 9 196 295         |  NP_SG PRES_SG NP_SG                 |                              $ | reduce by NP -> NP_SG              |
# | (17) | 0 9 196 330         |  NP_SG PRES_SG NP                    |                              $ | reduce by S1 -> NP                 |
# | (18) | 0 9 196 329         |  NP_SG PRES_SG S1                    |                              $ | reduce by S -> NP_SG PRES_SG S1    |
# | (19) | 0 129               |  S                                   |                              $ | accept                             |
# +------+---------------------+--------------------------------------+--------------------------------+------------------------------------+
# +-----+---------+-------------+------------------------------------------+------------------------------------------------+
# |     |  STACK  |   SYMBOLS   |                  INPUT                   |                     ACTION                     |
# +-----+---------+-------------+------------------------------------------+------------------------------------------------+
# | (1) | 0       |             | ishwarya will sings a song in the show $ | shift                                          |
# | (2) | 0 28    |  ishwarya   |          will sings a song in the show $ | reduce by PROPERNOUN -> ishwarya               |
# | (3) | 0 133   |  PROPERNOUN |          will sings a song in the show $ | reduce by NP_SG -> PROPERNOUN                  |
# | (4) | 0 9     |  NP_SG      |          will sings a song in the show $ | shift                                          |
# | (5) | 0 9 224 |  NP_SG will |               sings a song in the show $ | ERROR: input cannot be parsed by given grammar |
# +-----+---------+-------------+------------------------------------------+------------------------------------------------+
# Correction :
# Ishwarya will sing a song in the show
# +-----+-----------+-----------------+-------------------------------+------------------------------------------------+
# |     |   STACK   |     SYMBOLS     |             INPUT             |                     ACTION                     |
# +-----+-----------+-----------------+-------------------------------+------------------------------------------------+
# | (1) | 0         |                 | these people is from canada $ | shift                                          |
# | (2) | 0 165     |  these          |       people is from canada $ | reduce by DET_PL -> these                      |
# | (3) | 0 125     |  DET_PL         |       people is from canada $ | shift                                          |
# | (4) | 0 125 88  |  DET_PL people  |              is from canada $ | reduce by NOUN_PL -> people                    |
# | (5) | 0 125 74  |  DET_PL NOUN_PL |              is from canada $ | reduce by NOM_PL -> NOUN_PL                    |
# | (6) | 0 125 288 |  DET_PL NOM_PL  |              is from canada $ | reduce by NP_PL -> DET_PL NOM_PL               |
# | (7) | 0 26      |  NP_PL          |              is from canada $ | ERROR: input cannot be parsed by given grammar |
# +-----+-----------+-----------------+-------------------------------+------------------------------------------------+
# Correction :
# these people are from Canada

# %%
outputLines.append("Incorrect sentences count : {}\n\n".format(incorrectSentenceCount))
outputLines.append("---------------------------------------------\n\n")
for result in incorrectSentenceResult :
  outputLines.append(result)
outputLines.append("---------------------------------------------\n\n")

# %%
# WRITING RESULT TO THE OUTPUT FILE

outputFile = open("output.txt", "w")
for line in outputLines:
  outputFile.write(line)
outputFile.close()
